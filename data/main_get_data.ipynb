# %%
from get_data import get_data
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# initialization
main = get_data()

# %%
main.get_stock_list()

# %%
main.get_daily_trading_data()

# %%
main.get_weekly_trading_data()

# %%
main.get_monthly_trading_data()

# %%
main.get_balance_sheet()

# %%
main.get_income_statement()

# %%
main.get_cashflow_statement()

# %%
main.get_financial_indicator()

# %%
main.get_audit_opinion()

# %%
main.get_stock_index()

# %%
main.get_stock_name_histories()

# %%
main.get_index_daily_trading_data()

# %%
main.get_index_weekly_trading_data()

# %%
main.get_index_monthly_trading_data()

# %%
main.get_market_weekly_trading_data()

# %%
main.get_stock_daily_indicator()

# %%
main.get_stock_dividend()

# %%
main.get_stock_top10_holders()

# %%
main.get_stock_top10_common_holders()

# %%
main.get_stock_pcf()

# %%
main.get_quarterly_factors()

# %%
main.get_final_factor_monthly()

# %%
main.get_final_label_monthly()
