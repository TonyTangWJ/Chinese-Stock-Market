# %%
import pandas as pd
import warnings
from model import LinearRegression, ElasticNet, NN, RandomForest, K_Means_NN, XGBoost, CNN, Encoder
from utils import LoadData
from rolling_train_test import RollingTrainTest
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# **close**
# 1. data: cleaned;mse
# 2. data: ma12;mse
# 3. data: ma12_interaction_0.01_R;mse[废弃]
# 4. data: ma12_interaction_0.5;mse[废弃]
#
# **high**
# 1. data: cleaned;mse
# 2. data: ma12;mse
# 3. data: ma12_interaction_0.01_R;mse[废弃]
# 4. data: ma12_interaction_0.5;mse[废弃]
#
# **lr=0.001, mean=0, std=0.1**

# %%
'''close; clean; mse'''
factor = pd.read_csv('../CSV/factor_cleaned.csv')
input_dim = factor.shape[1] - 2
# print(f"Input dimension: {input_dim}")

label = pd.read_csv('../CSV/label_cleaned.csv')
# label.describe()
target = 3

# load data and model
Data = LoadData(factor, label, batch_size=32, num_workers=0, shuffle=True)
model_list = [
    LinearRegression(input_dim, target=target, model_name="LinearRegression"),
    ElasticNet(input_dim, target=target, alpha=0.5, l1_ratio=1, model_name="Lasso"),
    ElasticNet(input_dim, target=target, alpha=0.8, l1_ratio=0.5, model_name="ElasticNet"),
    RandomForest(n_estimators=100, target=target, max_depth=5, model_name="RandomForest"),
    XGBoost(target=target, n_estimators=100, max_depth=5, learning_rate=0.05, model_name="XGBoost"),
    CNN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, model_name="CNN"),
    NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, layer=2, model_name="NN"),
    NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, layer=3, model_name="NN"),
    NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, layer=4, model_name="NN"),
    NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, layer=5, model_name="NN"),
    K_Means_NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, n_clusters=10, layer=5, model_name="K_Means_NN"),
    Encoder(input_dim, target=target, nlayer=1, flayer=4, d_model=32, nhead=1, dropout=0.1, alpha=0.8, l1_ratio=0.5, model_name="Encoder")
]

# rolling test
count = 0
for model in model_list:
    RTT = RollingTrainTest(model, Data, train_size=0.5, test_size=0.1, epochs=20, patience=3, criterion=None, count=count)
    RTT.info(
        predictability_name = '[--clean--|--close--|--mse--|--epochs=20--]'
        )
    RTT.run()
    RTT.backtest(trade_mode=1)
    count += 1
    print(f"Model {model.model_name} backtest completed...")
    print("=" * 50)
# Out:
# LinearRegression will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9911
# No.1 Test Predictability: 0.0484
# No.1 Train Predictability: 0.0320
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0381
# No.2 Train Predictability: 0.0395
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0719
# No.3 Train Predictability: 0.0613
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0828
# No.4 Train Predictability: 0.0588
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0412
# No.5 Train Predictability: 0.0496
# Predictability of LinearRegression: 0.0565
# Model LinearRegression backtest completed...
# ==================================================
# Lasso will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.1 Test Predictability: 0.0138
# No.1 Train Predictability: 0.0132
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0123
# No.2 Train Predictability: 0.0109
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0074
# No.3 Train Predictability: 0.0063
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0302
# No.4 Train Predictability: 0.0229
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0261
# No.5 Train Predictability: 0.0277
# Predictability of Lasso: 0.0180
# Model Lasso backtest completed...
# ==================================================
# ElasticNet will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.1 Test Predictability: 0.0024
# No.1 Train Predictability: 0.0019
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0019
# No.2 Train Predictability: 0.0013
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0245
# No.3 Train Predictability: 0.0220
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0093
# No.4 Train Predictability: 0.0082
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0289
# No.5 Train Predictability: 0.0260
# Predictability of ElasticNet: 0.0134
# Model ElasticNet backtest completed...
# ==================================================
# RandomForest will run 5 iterations.
# No.1 Test Predictability: 0.0742
# No.1 Train Predictability: 0.0662
# No.2 Test Predictability: 0.0489
# No.2 Train Predictability: 0.0508
# No.3 Test Predictability: 0.0578
# No.3 Train Predictability: 0.0471
# No.4 Test Predictability: 0.0682
# No.4 Train Predictability: 0.0520
# No.5 Test Predictability: 0.0530
# No.5 Train Predictability: 0.0489
# Predictability of RandomForest: 0.0604
# Model RandomForest backtest completed...
# ==================================================
# XGBoost will run 5 iterations.
# No.1 Test Predictability: 0.0843
# No.1 Train Predictability: 0.0891
# No.2 Test Predictability: 0.0588
# No.2 Train Predictability: 0.0762
# No.3 Test Predictability: 0.0671
# No.3 Train Predictability: 0.0667
# No.4 Test Predictability: 0.0832
# No.4 Train Predictability: 0.0689
# No.5 Test Predictability: 0.0519
# No.5 Train Predictability: 0.0635
# Predictability of XGBoost: 0.0691
# Model XGBoost backtest completed...
# ==================================================
# CNN will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.1 Test Predictability: 0.0678
# No.1 Train Predictability: 0.0638
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0202
# No.2 Train Predictability: 0.0205
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0000
# No.3 Train Predictability: 0.0000
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0000
# No.4 Train Predictability: 0.0000
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0101
# No.5 Train Predictability: 0.0106
# Predictability of CNN: 0.0196
# Model CNN backtest completed...
# ==================================================
# NN_2Layers will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9806
# No.1 Test Predictability: 0.0875
# No.1 Train Predictability: 0.0808
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0774
# No.2 Train Predictability: 0.0841
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0585
# No.3 Train Predictability: 0.0553
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0803
# No.4 Train Predictability: 0.0663
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0558
# No.5 Train Predictability: 0.0657
# Predictability of NN_2Layers: 0.0719
# Model NN_2Layers backtest completed...
# ==================================================
# NN_3Layers will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9773
# Epoch [20/20], Loss: 0.9730
# No.1 Test Predictability: 0.0776
# No.1 Train Predictability: 0.0810
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0654
# No.2 Train Predictability: 0.0744
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9776
# No.3 Test Predictability: 0.0594
# No.3 Train Predictability: 0.0711
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0881
# No.4 Train Predictability: 0.0827
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0487
# No.5 Train Predictability: 0.0718
# Predictability of NN_3Layers: 0.0678
# Model NN_3Layers backtest completed...
# ==================================================
# NN_4Layers will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9758
# No.1 Test Predictability: 0.1015
# No.1 Train Predictability: 0.0965
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0738
# No.2 Train Predictability: 0.0896
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0698
# No.3 Train Predictability: 0.0721
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0804
# No.4 Train Predictability: 0.0713
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0547
# No.5 Train Predictability: 0.0865
# Predictability of NN_4Layers: 0.0760
# Model NN_4Layers backtest completed...
# ==================================================
# NN_5Layers will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9764
# No.1 Test Predictability: 0.0946
# No.1 Train Predictability: 0.0940
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0547
# No.2 Train Predictability: 0.0770
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0590
# No.3 Train Predictability: 0.0649
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0994
# No.4 Train Predictability: 0.0935
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0408
# No.5 Train Predictability: 0.0599
# Predictability of NN_5Layers: 0.0697
# Model NN_5Layers backtest completed...
# ==================================================
# K_Means_NN_5Layers_10Clusters will run 5 iterations.
# K-means clustering completed:
#   Cluster 0: 13389 samples (8.4%)
#   Cluster 1: 17798 samples (11.1%)
#   Cluster 2: 12982 samples (8.1%)
#   Cluster 3: 16545 samples (10.4%)
#   Cluster 4: 6484 samples (4.1%)
#   Cluster 5: 24279 samples (15.2%)
#   Cluster 6: 47446 samples (29.7%)
#   Cluster 7: 4389 samples (2.7%)
#   Cluster 8: 8929 samples (5.6%)
#   Cluster 9: 7606 samples (4.8%)
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.1 Test Predictability: 0.0655
# No.1 Train Predictability: 0.0496
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0445
# No.2 Train Predictability: 0.0426
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0522
# No.3 Train Predictability: 0.0447
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0628
# No.4 Train Predictability: 0.0466
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0459
# No.5 Train Predictability: 0.0457
# Predictability of K_Means_NN_5Layers_10Clusters: 0.0542
# Model K_Means_NN_5Layers_10Clusters backtest completed...
# ==================================================
# Encoder_1nLayers_1Heads_4Flayers_32DModel_0.1Dropout will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9773
# No.1 Test Predictability: 0.0870
# No.1 Train Predictability: 0.0953
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0386
# No.2 Train Predictability: 0.0591
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0897
# No.3 Train Predictability: 0.0899
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0792
# No.4 Train Predictability: 0.0732
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0340
# No.5 Train Predictability: 0.0665
# Predictability of Encoder_1nLayers_1Heads_4Flayers_32DModel_0.1Dropout: 0.0657
# Model Encoder_1nLayers_1Heads_4Flayers_32DModel_0.1Dropout backtest completed...
# ==================================================

# %%
'''close; ma12; mse'''
factor = pd.read_csv('../CSV/factor_ma12.csv')
input_dim = factor.shape[1] - 2
# print(f"Input dimension: {input_dim}")

label = pd.read_csv('../CSV/label_cleaned.csv')
# label.describe()
target = 3

# load data and model
Data = LoadData(factor, label, batch_size=32, num_workers=0, shuffle=True)
model_list = [
    LinearRegression(input_dim, target=target, model_name="LinearRegression"),
    ElasticNet(input_dim, target=target, alpha=0.5, l1_ratio=1, model_name="Lasso"),
    ElasticNet(input_dim, target=target, alpha=0.8, l1_ratio=0.5, model_name="ElasticNet"),
    RandomForest(n_estimators=100, target=target, max_depth=5, model_name="RandomForest"),
    XGBoost(target=target, n_estimators=100, max_depth=5, learning_rate=0.05, model_name="XGBoost"),
    CNN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, model_name="CNN"),
    NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, layer=2, model_name="NN"),
    NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, layer=3, model_name="NN"),
    NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, layer=4, model_name="NN"),
    NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, layer=5, model_name="NN"),
    K_Means_NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, n_clusters=10, layer=5, model_name="K_Means_NN"),
    Encoder(input_dim, target=target, nlayer=1, flayer=4, d_model=32, nhead=1, dropout=0.1, alpha=0.8, l1_ratio=0.5, model_name="Encoder")
]

# rolling test
count = 0
for model in model_list:
    RTT = RollingTrainTest(model, Data, train_size=0.5, test_size=0.1, epochs=20, patience=3, criterion=None, count=count)
    RTT.info(
        predictability_name = '[--ma12--|--close--|--mse--|--epochs=20--]'
        )
    RTT.run()
    RTT.backtest(trade_mode=1)
    count += 1
    print(f"Model {model.model_name} backtest completed...")
    print("=" * 50)
# Out:
# LinearRegression will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.1 Test Predictability: 0.0944
# No.1 Train Predictability: 0.0706
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0602
# No.2 Train Predictability: 0.0626
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0420
# No.3 Train Predictability: 0.0468
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0688
# No.4 Train Predictability: 0.0457
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0232
# No.5 Train Predictability: 0.0228
# Predictability of LinearRegression: 0.0577
# Model LinearRegression backtest completed...
# ==================================================
# Lasso will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.1 Test Predictability: 0.0083
# No.1 Train Predictability: 0.0066
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0001
# No.2 Train Predictability: 0.0000
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0052
# No.3 Train Predictability: 0.0053
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0034
# No.4 Train Predictability: 0.0022
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0015
# No.5 Train Predictability: 0.0011
# Predictability of Lasso: 0.0037
# Model Lasso backtest completed...
# ==================================================
# ElasticNet will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.1 Test Predictability: 0.0187
# No.1 Train Predictability: 0.0178
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0076
# No.2 Train Predictability: 0.0064
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0020
# No.3 Train Predictability: 0.0027
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0008
# No.4 Train Predictability: 0.0004
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0077
# No.5 Train Predictability: 0.0086
# Predictability of ElasticNet: 0.0074
# Model ElasticNet backtest completed...
# ==================================================
# RandomForest will run 5 iterations.
# No.1 Test Predictability: 0.0633
# No.1 Train Predictability: 0.0671
# No.2 Test Predictability: 0.0434
# No.2 Train Predictability: 0.0581
# No.3 Test Predictability: 0.0451
# No.3 Train Predictability: 0.0519
# No.4 Test Predictability: 0.0598
# No.4 Train Predictability: 0.0461
# No.5 Test Predictability: 0.0469
# No.5 Train Predictability: 0.0420
# Predictability of RandomForest: 0.0517
# Model RandomForest backtest completed...
# ==================================================
# XGBoost will run 5 iterations.
# No.1 Test Predictability: 0.0883
# No.1 Train Predictability: 0.0943
# No.2 Test Predictability: 0.0495
# No.2 Train Predictability: 0.0806
# No.3 Test Predictability: 0.0512
# No.3 Train Predictability: 0.0735
# No.4 Test Predictability: 0.0790
# No.4 Train Predictability: 0.0674
# No.5 Test Predictability: 0.0561
# No.5 Train Predictability: 0.0606
# Predictability of XGBoost: 0.0648
# Model XGBoost backtest completed...
# ==================================================
# CNN will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.1 Test Predictability: 0.0207
# No.1 Train Predictability: 0.0188
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0576
# No.2 Train Predictability: 0.0494
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0382
# No.3 Train Predictability: 0.0372
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0401
# No.4 Train Predictability: 0.0331
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0349
# No.5 Train Predictability: 0.0310
# Predictability of CNN: 0.0383
# Model CNN backtest completed...
# ==================================================
# NN_2Layers will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9791
# No.1 Test Predictability: 0.0803
# No.1 Train Predictability: 0.0750
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0483
# No.2 Train Predictability: 0.0778
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0343
# No.3 Train Predictability: 0.0535
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0791
# No.4 Train Predictability: 0.0647
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0584
# No.5 Train Predictability: 0.0535
# Predictability of NN_2Layers: 0.0601
# Model NN_2Layers backtest completed...
# ==================================================
# NN_3Layers will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9755
# Epoch [20/20], Loss: 0.9712
# No.1 Test Predictability: 0.0756
# No.1 Train Predictability: 0.0947
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0518
# No.2 Train Predictability: 0.0977
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0584
# No.3 Train Predictability: 0.0851
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0861
# No.4 Train Predictability: 0.0744
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0557
# No.5 Train Predictability: 0.0584
# Predictability of NN_3Layers: 0.0655
# Model NN_3Layers backtest completed...
# ==================================================
# NN_4Layers will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9734
# No.1 Test Predictability: 0.0902
# No.1 Train Predictability: 0.0969
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9741
# No.2 Test Predictability: 0.0316
# No.2 Train Predictability: 0.0783
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0617
# No.3 Train Predictability: 0.0974
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0531
# No.4 Train Predictability: 0.0556
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0663
# No.5 Train Predictability: 0.0850
# Predictability of NN_4Layers: 0.0606
# Model NN_4Layers backtest completed...
# ==================================================
# NN_5Layers will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9731
# No.1 Test Predictability: 0.1054
# No.1 Train Predictability: 0.1039
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9756
# No.2 Test Predictability: 0.0379
# No.2 Train Predictability: 0.0805
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0459
# No.3 Train Predictability: 0.0783
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0634
# No.4 Train Predictability: 0.0658
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0422
# No.5 Train Predictability: 0.0545
# Predictability of NN_5Layers: 0.0590
# Model NN_5Layers backtest completed...
# ==================================================
# K_Means_NN_5Layers_10Clusters will run 5 iterations.
# K-means clustering completed:
#   Cluster 0: 37739 samples (23.6%)
#   Cluster 1: 8032 samples (5.0%)
#   Cluster 2: 15969 samples (10.0%)
#   Cluster 3: 25153 samples (15.7%)
#   Cluster 4: 7854 samples (4.9%)
#   Cluster 5: 10830 samples (6.8%)
#   Cluster 6: 14507 samples (9.1%)
#   Cluster 7: 15991 samples (10.0%)
#   Cluster 8: 4651 samples (2.9%)
#   Cluster 9: 19121 samples (12.0%)
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.1 Test Predictability: 0.0522
# No.1 Train Predictability: 0.0391
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0405
# No.2 Train Predictability: 0.0476
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0387
# No.3 Train Predictability: 0.0374
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0622
# No.4 Train Predictability: 0.0419
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0534
# No.5 Train Predictability: 0.0451
# Predictability of K_Means_NN_5Layers_10Clusters: 0.0494
# Model K_Means_NN_5Layers_10Clusters backtest completed...
# ==================================================
# Encoder_1nLayers_1Heads_4Flayers_32DModel_0.1Dropout will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9745
# No.1 Test Predictability: 0.0952
# No.1 Train Predictability: 0.0888
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9752
# No.2 Test Predictability: 0.0242
# No.2 Train Predictability: 0.0522
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0393
# No.3 Train Predictability: 0.0600
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0650
# No.4 Train Predictability: 0.0663
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0472
# No.5 Train Predictability: 0.0530
# Predictability of Encoder_1nLayers_1Heads_4Flayers_32DModel_0.1Dropout: 0.0542
# Model Encoder_1nLayers_1Heads_4Flayers_32DModel_0.1Dropout backtest completed...
# ==================================================

# %%
'''high; clean; mse'''
factor = pd.read_csv('../CSV/factor_cleaned.csv')
input_dim = factor.shape[1] - 2
# print(f"Input dimension: {input_dim}")

label = pd.read_csv('../CSV/label_cleaned.csv')
# label.describe()
target = 1

# load data and model
Data = LoadData(factor, label, batch_size=32, num_workers=0, shuffle=True)
model_list = [
    LinearRegression(input_dim, target=target, model_name="LinearRegression"),
    ElasticNet(input_dim, target=target, alpha=0.5, l1_ratio=1, model_name="Lasso"),
    ElasticNet(input_dim, target=target, alpha=0.8, l1_ratio=0.5, model_name="ElasticNet"),
    RandomForest(n_estimators=100, target=target, max_depth=5, model_name="RandomForest"),
    XGBoost(target=target, n_estimators=100, max_depth=5, learning_rate=0.05, model_name="XGBoost"),
    CNN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, model_name="CNN"),
    NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, layer=2, model_name="NN"),
    NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, layer=3, model_name="NN"),
    NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, layer=4, model_name="NN"),
    NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, layer=5, model_name="NN"),
    K_Means_NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, n_clusters=10, layer=5, model_name="K_Means_NN"),
    Encoder(input_dim, target=target, nlayer=1, flayer=4, d_model=32, nhead=1, dropout=0.1, alpha=0.8, l1_ratio=0.5, model_name="Encoder")
]

# rolling test
count = 0
for model in model_list:
    RTT = RollingTrainTest(model, Data, train_size=0.5, test_size=0.1, epochs=20, patience=3, criterion=None, count=count)
    RTT.info(
        predictability_name = '[--clean--|--high--|--mse--|--epochs=20--]'
        )
    RTT.run()
    RTT.backtest(trade_mode=2)
    count += 1
    print(f"Model {model.model_name} backtest completed...")
    print("=" * 50)
# Out:
# LinearRegression will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.1 Test Predictability: 0.0995
# No.1 Train Predictability: 0.1532
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0911
# No.2 Train Predictability: 0.1405
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.1205
# No.3 Train Predictability: 0.1547
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0928
# No.4 Train Predictability: 0.1290
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.1348
# No.5 Train Predictability: 0.1275
# Predictability of LinearRegression: 0.1077
# Model LinearRegression backtest completed...
# ==================================================
# Lasso will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9730
# No.1 Test Predictability: 0.0830
# No.1 Train Predictability: 0.1180
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.1012
# No.2 Train Predictability: 0.1446
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.1018
# No.3 Train Predictability: 0.1280
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0731
# No.4 Train Predictability: 0.0960
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.1308
# No.5 Train Predictability: 0.1199
# Predictability of Lasso: 0.0980
# Model Lasso backtest completed...
# ==================================================
# ElasticNet will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9708
# No.1 Test Predictability: 0.0782
# No.1 Train Predictability: 0.1208
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.1060
# No.2 Train Predictability: 0.1389
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.1050
# No.3 Train Predictability: 0.1258
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0799
# No.4 Train Predictability: 0.0962
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.1010
# No.5 Train Predictability: 0.0984
# Predictability of ElasticNet: 0.0940
# Model ElasticNet backtest completed...
# ==================================================
# RandomForest will run 5 iterations.
# No.1 Test Predictability: 0.1119
# No.1 Train Predictability: 0.1753
# No.2 Test Predictability: 0.1158
# No.2 Train Predictability: 0.1570
# No.3 Test Predictability: 0.1222
# No.3 Train Predictability: 0.1481
# No.4 Test Predictability: 0.1064
# No.4 Train Predictability: 0.1413
# No.5 Test Predictability: 0.1461
# No.5 Train Predictability: 0.1424
# Predictability of RandomForest: 0.1205
# Model RandomForest backtest completed...
# ==================================================
# XGBoost will run 5 iterations.
# No.1 Test Predictability: 0.1185
# No.1 Train Predictability: 0.2010
# No.2 Test Predictability: 0.1115
# No.2 Train Predictability: 0.1819
# No.3 Test Predictability: 0.1206
# No.3 Train Predictability: 0.1677
# No.4 Test Predictability: 0.1095
# No.4 Train Predictability: 0.1569
# No.5 Test Predictability: 0.1434
# No.5 Train Predictability: 0.1579
# Predictability of XGBoost: 0.1207
# Model XGBoost backtest completed...
# ==================================================
# CNN will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9867
# No.1 Test Predictability: 0.0592
# No.1 Train Predictability: 0.0665
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0646
# No.2 Train Predictability: 0.0635
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0581
# No.3 Train Predictability: 0.0555
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0575
# No.4 Train Predictability: 0.0542
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0774
# No.5 Train Predictability: 0.0607
# Predictability of CNN: 0.0634
# Model CNN backtest completed...
# ==================================================
# NN_2Layers will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9129
# No.1 Test Predictability: 0.1275
# No.1 Train Predictability: 0.1959
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9185
# No.2 Test Predictability: 0.1143
# No.2 Train Predictability: 0.1727
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.1088
# No.3 Train Predictability: 0.1540
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.1133
# No.4 Train Predictability: 0.1654
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.1211
# No.5 Train Predictability: 0.1433
# Predictability of NN_2Layers: 0.1170
# Model NN_2Layers backtest completed...
# ==================================================
# NN_3Layers will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9079
# No.1 Test Predictability: 0.1237
# No.1 Train Predictability: 0.2030
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9129
# No.2 Test Predictability: 0.1076
# No.2 Train Predictability: 0.1747
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.1241
# No.3 Train Predictability: 0.1770
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.1047
# No.4 Train Predictability: 0.1615
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.1262
# No.5 Train Predictability: 0.1518
# Predictability of NN_3Layers: 0.1173
# Model NN_3Layers backtest completed...
# ==================================================
# NN_4Layers will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9054
# No.1 Test Predictability: 0.1246
# No.1 Train Predictability: 0.1945
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.1034
# No.2 Train Predictability: 0.1766
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.1141
# No.3 Train Predictability: 0.1707
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0903
# No.4 Train Predictability: 0.1352
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.1373
# No.5 Train Predictability: 0.1566
# Predictability of NN_4Layers: 0.1139
# Model NN_4Layers backtest completed...
# ==================================================
# NN_5Layers will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9078
# Epoch [20/20], Loss: 0.9022
# No.1 Test Predictability: 0.1357
# No.1 Train Predictability: 0.2079
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9129
# No.2 Test Predictability: 0.1312
# No.2 Train Predictability: 0.2019
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.1184
# No.3 Train Predictability: 0.1731
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.1026
# No.4 Train Predictability: 0.1551
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.1320
# No.5 Train Predictability: 0.1546
# Predictability of NN_5Layers: 0.1240
# Model NN_5Layers backtest completed...
# ==================================================
# K_Means_NN_5Layers_10Clusters will run 5 iterations.
# K-means clustering completed:
#   Cluster 0: 26208 samples (16.4%)
#   Cluster 1: 5563 samples (3.5%)
#   Cluster 2: 16028 samples (10.0%)
#   Cluster 3: 8647 samples (5.4%)
#   Cluster 4: 8639 samples (5.4%)
#   Cluster 5: 43166 samples (27.0%)
#   Cluster 6: 18279 samples (11.4%)
#   Cluster 7: 13828 samples (8.7%)
#   Cluster 8: 13761 samples (8.6%)
#   Cluster 9: 5728 samples (3.6%)
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.1 Test Predictability: 0.1172
# No.1 Train Predictability: 0.1719
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.1150
# No.2 Train Predictability: 0.1612
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.1154
# No.3 Train Predictability: 0.1434
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.1112
# No.4 Train Predictability: 0.1397
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.1444
# No.5 Train Predictability: 0.1431
# Predictability of K_Means_NN_5Layers_10Clusters: 0.1206
# Model K_Means_NN_5Layers_10Clusters backtest completed...
# ==================================================
# Encoder_1nLayers_1Heads_4Flayers_32DModel_0.1Dropout will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9077
# Epoch [20/20], Loss: 0.9002
# No.1 Test Predictability: 0.1277
# No.1 Train Predictability: 0.2094
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.1136
# No.2 Train Predictability: 0.1853
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.1133
# No.3 Train Predictability: 0.1745
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.1098
# No.4 Train Predictability: 0.1808
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.1211
# No.5 Train Predictability: 0.1365
# Predictability of Encoder_1nLayers_1Heads_4Flayers_32DModel_0.1Dropout: 0.1171
# Model Encoder_1nLayers_1Heads_4Flayers_32DModel_0.1Dropout backtest completed...
# ==================================================

# %%
'''high; ma12; mse'''
factor = pd.read_csv('../CSV/factor_ma12.csv')
input_dim = factor.shape[1] - 2
# print(f"Input dimension: {input_dim}")

label = pd.read_csv('../CSV/label_cleaned.csv')
# label.describe()
target = 1

# load data and model
Data = LoadData(factor, label, batch_size=32, num_workers=0, shuffle=True)
model_list = [
    LinearRegression(input_dim, target=target, model_name="LinearRegression"),
    ElasticNet(input_dim, target=target, alpha=0.5, l1_ratio=1, model_name="Lasso"),
    ElasticNet(input_dim, target=target, alpha=0.8, l1_ratio=0.5, model_name="ElasticNet"),
    RandomForest(n_estimators=100, target=target, max_depth=5, model_name="RandomForest"),
    XGBoost(target=target, n_estimators=100, max_depth=5, learning_rate=0.05, model_name="XGBoost"),
    CNN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, model_name="CNN"),
    NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, layer=2, model_name="NN"),
    NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, layer=3, model_name="NN"),
    NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, layer=4, model_name="NN"),
    NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, layer=5, model_name="NN"),
    K_Means_NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, n_clusters=10, layer=5, model_name="K_Means_NN"),
    Encoder(input_dim, target=target, nlayer=1, flayer=4, d_model=32, nhead=1, dropout=0.1, alpha=0.8, l1_ratio=0.5, model_name="Encoder")
]

# rolling test
count = 0
for model in model_list:
    RTT = RollingTrainTest(model, Data, train_size=0.5, test_size=0.1, epochs=20, patience=3, criterion=None, count=count)
    RTT.info(
        predictability_name = '[--ma12--|--high--|--mse--|--epochs=20--]'
        )
    RTT.run()
    RTT.backtest(trade_mode=2)
    count += 1
    print(f"Model {model.model_name} backtest completed...")
    print("=" * 50)
# Out:
# LinearRegression will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.1 Test Predictability: 0.1027
# No.1 Train Predictability: 0.1488
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0632
# No.2 Train Predictability: 0.1162
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0997
# No.3 Train Predictability: 0.1190
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0933
# No.4 Train Predictability: 0.1134
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.1125
# No.5 Train Predictability: 0.1290
# Predictability of LinearRegression: 0.0943
# Model LinearRegression backtest completed...
# ==================================================
# Lasso will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9863
# No.1 Test Predictability: 0.0644
# No.1 Train Predictability: 0.1001
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0837
# No.2 Train Predictability: 0.1200
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0750
# No.3 Train Predictability: 0.0860
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0837
# No.4 Train Predictability: 0.1045
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0898
# No.5 Train Predictability: 0.0993
# Predictability of Lasso: 0.0793
# Model Lasso backtest completed...
# ==================================================
# ElasticNet will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9849
# No.1 Test Predictability: 0.0847
# No.1 Train Predictability: 0.1341
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0613
# No.2 Train Predictability: 0.1060
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0982
# No.3 Train Predictability: 0.1141
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0788
# No.4 Train Predictability: 0.0899
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0688
# No.5 Train Predictability: 0.0902
# Predictability of ElasticNet: 0.0784
# Model ElasticNet backtest completed...
# ==================================================
# RandomForest will run 5 iterations.
# No.1 Test Predictability: 0.0973
# No.1 Train Predictability: 0.1439
# No.2 Test Predictability: 0.0738
# No.2 Train Predictability: 0.1275
# No.3 Test Predictability: 0.0953
# No.3 Train Predictability: 0.1192
# No.4 Test Predictability: 0.0875
# No.4 Train Predictability: 0.1159
# No.5 Test Predictability: 0.0989
# No.5 Train Predictability: 0.1182
# Predictability of RandomForest: 0.0906
# Model RandomForest backtest completed...
# ==================================================
# XGBoost will run 5 iterations.
# No.1 Test Predictability: 0.1162
# No.1 Train Predictability: 0.1698
# No.2 Test Predictability: 0.0761
# No.2 Train Predictability: 0.1509
# No.3 Test Predictability: 0.0983
# No.3 Train Predictability: 0.1397
# No.4 Test Predictability: 0.0961
# No.4 Train Predictability: 0.1333
# No.5 Test Predictability: 0.0981
# No.5 Train Predictability: 0.1331
# Predictability of XGBoost: 0.0970
# Model XGBoost backtest completed...
# ==================================================
# CNN will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.1 Test Predictability: 0.0722
# No.1 Train Predictability: 0.0637
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0670
# No.2 Train Predictability: 0.0537
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0698
# No.3 Train Predictability: 0.0665
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0614
# No.4 Train Predictability: 0.0544
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0669
# No.5 Train Predictability: 0.0541
# Predictability of CNN: 0.0675
# Model CNN backtest completed...
# ==================================================
# NN_2Layers will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9353
# No.1 Test Predictability: 0.1241
# No.1 Train Predictability: 0.1600
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0802
# No.2 Train Predictability: 0.1540
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.1007
# No.3 Train Predictability: 0.1291
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.1004
# No.4 Train Predictability: 0.1343
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9512
# No.5 Test Predictability: 0.1237
# No.5 Train Predictability: 0.1628
# Predictability of NN_2Layers: 0.1058
# Model NN_2Layers backtest completed...
# ==================================================
# NN_3Layers will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9318
# Epoch [20/20], Loss: 0.9261
# No.1 Test Predictability: 0.1161
# No.1 Train Predictability: 0.1761
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9367
# No.2 Test Predictability: 0.0731
# No.2 Train Predictability: 0.1498
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0998
# No.3 Train Predictability: 0.1434
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0881
# No.4 Train Predictability: 0.1364
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.1000
# No.5 Train Predictability: 0.1377
# Predictability of NN_3Layers: 0.0954
# Model NN_3Layers backtest completed...
# ==================================================
# NN_4Layers will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9296
# Epoch [20/20], Loss: 0.9236
# No.1 Test Predictability: 0.1072
# No.1 Train Predictability: 0.1600
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0666
# No.2 Train Predictability: 0.1607
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.1123
# No.3 Train Predictability: 0.1544
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0860
# No.4 Train Predictability: 0.1228
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0945
# No.5 Train Predictability: 0.1378
# Predictability of NN_4Layers: 0.0933
# Model NN_4Layers backtest completed...
# ==================================================
# NN_5Layers will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9308
# No.1 Test Predictability: 0.1189
# No.1 Train Predictability: 0.1813
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9352
# No.2 Test Predictability: 0.0549
# No.2 Train Predictability: 0.1379
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.1000
# No.3 Train Predictability: 0.1406
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0856
# No.4 Train Predictability: 0.1427
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0866
# No.5 Train Predictability: 0.1358
# Predictability of NN_5Layers: 0.0892
# Model NN_5Layers backtest completed...
# ==================================================
# K_Means_NN_5Layers_10Clusters will run 5 iterations.
# K-means clustering completed:
#   Cluster 0: 25124 samples (15.7%)
#   Cluster 1: 4672 samples (2.9%)
#   Cluster 2: 19085 samples (11.9%)
#   Cluster 3: 14660 samples (9.2%)
#   Cluster 4: 10651 samples (6.7%)
#   Cluster 5: 15987 samples (10.0%)
#   Cluster 6: 7913 samples (5.0%)
#   Cluster 7: 38054 samples (23.8%)
#   Cluster 8: 7867 samples (4.9%)
#   Cluster 9: 15834 samples (9.9%)
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.1 Test Predictability: 0.0928
# No.1 Train Predictability: 0.1249
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0666
# No.2 Train Predictability: 0.1197
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0933
# No.3 Train Predictability: 0.1110
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0916
# No.4 Train Predictability: 0.1091
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0944
# No.5 Train Predictability: 0.1052
# Predictability of K_Means_NN_5Layers_10Clusters: 0.0877
# Model K_Means_NN_5Layers_10Clusters backtest completed...
# ==================================================
# Encoder_1nLayers_1Heads_4Flayers_32DModel_0.1Dropout will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9309
# Epoch [20/20], Loss: 0.9251
# No.1 Test Predictability: 0.1015
# No.1 Train Predictability: 0.1737
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0528
# No.2 Train Predictability: 0.1301
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0892
# No.3 Train Predictability: 0.1285
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0811
# No.4 Train Predictability: 0.1113
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0812
# No.5 Train Predictability: 0.1086
# Predictability of Encoder_1nLayers_1Heads_4Flayers_32DModel_0.1Dropout: 0.0812
# Model Encoder_1nLayers_1Heads_4Flayers_32DModel_0.1Dropout backtest completed...
# ==================================================
