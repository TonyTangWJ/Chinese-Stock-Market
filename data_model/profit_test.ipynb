# %%
import pandas as pd
import warnings
from model import LinearRegression, ElasticNet, NN, RandomForest, K_Means_NN, XGBoost, CNN, Encoder
from utils import LoadData
from rolling_train_test import RollingTrainTest
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# **close**
# 1. data: cleaned;mse
# 2. data: ma12;mse
# 3. data: ma12_interaction_0.01_R;mse[废弃]
# 4. data: ma12_interaction_0.5;mse[废弃]
#
# **high**
# 1. data: cleaned;mse
# 2. data: ma12;mse
# 3. data: ma12_interaction_0.01_R;mse[废弃]
# 4. data: ma12_interaction_0.5;mse[废弃]
#
# **lr=0.001, mean=0, std=0.1**

# %%
'''close; clean; mse'''
factor = pd.read_csv('../CSV/factor_cleaned.csv')
input_dim = factor.shape[1] - 2
# print(f"Input dimension: {input_dim}")

label = pd.read_csv('../CSV/label_cleaned.csv')
# label.describe()
target = 3

# load data and model
Data = LoadData(factor, label, batch_size=32, num_workers=0, shuffle=True)
model_list = [
    LinearRegression(input_dim, target=target, model_name="LinearRegression"),
    ElasticNet(input_dim, target=target, alpha=0.5, l1_ratio=1, model_name="Lasso"),
    ElasticNet(input_dim, target=target, alpha=0.8, l1_ratio=0.5, model_name="ElasticNet"),
    RandomForest(n_estimators=100, target=target, max_depth=5, model_name="RandomForest"),
    XGBoost(target=target, n_estimators=100, max_depth=5, learning_rate=0.05, model_name="XGBoost"),
    CNN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, model_name="CNN"),
    NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, layer=1, model_name="NN"),
    NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, layer=2, model_name="NN"),
    NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, layer=3, model_name="NN"),
    NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, layer=4, model_name="NN"),
    NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, layer=5, model_name="NN"),
    K_Means_NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, n_clusters=10, layer=5, model_name="K_Means_NN"),
    Encoder(input_dim, target=target, nlayer=1, flayer=4, d_model=32, nhead=1, dropout=0.1, alpha=0.8, l1_ratio=0.5, model_name="Encoder")
]

# rolling test
count = 0
for model in model_list:
    RTT = RollingTrainTest(model, Data, train_size=0.5, test_size=0.1, epochs=20, patience=3, criterion=None, count=count)
    RTT.info(
        predictability_name = '[--clean--|--close--|--mse--|--epochs=20--]'
        )
    RTT.run()
    RTT.backtest(trade_mode=1)
    count += 1
    print(f"Model {model.model_name} backtest completed...")
    print("=" * 50)
# Out:
# LinearRegression will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.1 Test Predictability: 0.0884
# No.1 Train Predictability: 0.0654
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0509
# No.2 Train Predictability: 0.0504
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0775
# No.3 Train Predictability: 0.0610
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0537
# No.4 Train Predictability: 0.0364
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0332
# No.5 Train Predictability: 0.0366
# Predictability of LinearRegression: 0.0607
# Model LinearRegression backtest completed...
# ==================================================
# Lasso will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.1 Test Predictability: 0.0028
# No.1 Train Predictability: 0.0024
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0321
# No.2 Train Predictability: 0.0314
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0170
# No.3 Train Predictability: 0.0142
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0572
# No.4 Train Predictability: 0.0437
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0119
# No.5 Train Predictability: 0.0111
# Predictability of Lasso: 0.0242
# Model Lasso backtest completed...
# ==================================================
# ElasticNet will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.1 Test Predictability: 0.0103
# No.1 Train Predictability: 0.0077
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0195
# No.2 Train Predictability: 0.0178
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0123
# No.3 Train Predictability: 0.0110
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0130
# No.4 Train Predictability: 0.0097
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0206
# No.5 Train Predictability: 0.0204
# Predictability of ElasticNet: 0.0151
# Model ElasticNet backtest completed...
# ==================================================
# RandomForest will run 5 iterations.
# No.1 Test Predictability: 0.0745
# No.1 Train Predictability: 0.0661
# No.2 Test Predictability: 0.0488
# No.2 Train Predictability: 0.0514
# No.3 Test Predictability: 0.0580
# No.3 Train Predictability: 0.0476
# No.4 Test Predictability: 0.0681
# No.4 Train Predictability: 0.0522
# No.5 Test Predictability: 0.0524
# No.5 Train Predictability: 0.0488
# Predictability of RandomForest: 0.0604
# Model RandomForest backtest completed...
# ==================================================
# XGBoost will run 5 iterations.
# No.1 Test Predictability: 0.0861
# No.1 Train Predictability: 0.0894
# No.2 Test Predictability: 0.0579
# No.2 Train Predictability: 0.0751
# No.3 Test Predictability: 0.0664
# No.3 Train Predictability: 0.0672
# No.4 Test Predictability: 0.0817
# No.4 Train Predictability: 0.0686
# No.5 Test Predictability: 0.0517
# No.5 Train Predictability: 0.0639
# Predictability of XGBoost: 0.0688
# Model XGBoost backtest completed...
# ==================================================
# CNN will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9961
# No.1 Test Predictability: 0.0693
# No.1 Train Predictability: 0.0590
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0166
# No.2 Train Predictability: 0.0159
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0596
# No.3 Train Predictability: 0.0563
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0306
# No.4 Train Predictability: 0.0270
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0472
# No.5 Train Predictability: 0.0325
# Predictability of CNN: 0.0447
# Model CNN backtest completed...
# ==================================================
# NN_1Layers will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9800
# No.1 Test Predictability: 0.0839
# No.1 Train Predictability: 0.0797
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0849
# No.2 Train Predictability: 0.0950
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0627
# No.3 Train Predictability: 0.0647
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.1004
# No.4 Train Predictability: 0.0820
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0585
# No.5 Train Predictability: 0.0757
# Predictability of NN_1Layers: 0.0781
# Model NN_1Layers backtest completed...
# ==================================================
# NN_2Layers will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9762
# Epoch [20/20], Loss: 0.9718
# No.1 Test Predictability: 0.0976
# No.1 Train Predictability: 0.1053
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9760
# No.2 Test Predictability: 0.0543
# No.2 Train Predictability: 0.0708
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0701
# No.3 Train Predictability: 0.0793
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0747
# No.4 Train Predictability: 0.0708
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0612
# No.5 Train Predictability: 0.0813
# Predictability of NN_2Layers: 0.0716
# Model NN_2Layers backtest completed...
# ==================================================
# NN_3Layers will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9766
# Epoch [20/20], Loss: 0.9713
# No.1 Test Predictability: 0.1050
# No.1 Train Predictability: 0.1108
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0641
# No.2 Train Predictability: 0.0793
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0715
# No.3 Train Predictability: 0.0729
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0682
# No.4 Train Predictability: 0.0605
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0697
# No.5 Train Predictability: 0.0930
# Predictability of NN_3Layers: 0.0757
# Model NN_3Layers backtest completed...
# ==================================================
# NN_4Layers will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9762
# Epoch [20/20], Loss: 0.9715
# No.1 Test Predictability: 0.0992
# No.1 Train Predictability: 0.1046
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0628
# No.2 Train Predictability: 0.0777
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0943
# No.3 Train Predictability: 0.1045
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0819
# No.4 Train Predictability: 0.0765
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0513
# No.5 Train Predictability: 0.0607
# Predictability of NN_4Layers: 0.0779
# Model NN_4Layers backtest completed...
# ==================================================
# NN_5Layers will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9777
# No.1 Test Predictability: 0.0763
# No.1 Train Predictability: 0.0768
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9762
# No.2 Test Predictability: 0.0648
# No.2 Train Predictability: 0.0833
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0575
# No.3 Train Predictability: 0.0658
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0757
# No.4 Train Predictability: 0.0711
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0594
# No.5 Train Predictability: 0.0820
# Predictability of NN_5Layers: 0.0667
# Model NN_5Layers backtest completed...
# ==================================================
# K_Means_NN_5Layers_10Clusters will run 5 iterations.
# K-means clustering completed:
#   Cluster 0: 47405 samples (29.7%)
#   Cluster 1: 4389 samples (2.7%)
#   Cluster 2: 16581 samples (10.4%)
#   Cluster 3: 13371 samples (8.4%)
#   Cluster 4: 6480 samples (4.1%)
#   Cluster 5: 7644 samples (4.8%)
#   Cluster 6: 8911 samples (5.6%)
#   Cluster 7: 17798 samples (11.1%)
#   Cluster 8: 24296 samples (15.2%)
#   Cluster 9: 12972 samples (8.1%)
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.1 Test Predictability: 0.0554
# No.1 Train Predictability: 0.0388
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0441
# No.2 Train Predictability: 0.0430
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0450
# No.3 Train Predictability: 0.0352
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0569
# No.4 Train Predictability: 0.0410
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0456
# No.5 Train Predictability: 0.0432
# Predictability of K_Means_NN_5Layers_10Clusters: 0.0494
# Model K_Means_NN_5Layers_10Clusters backtest completed...
# ==================================================
# Encoder_1nLayers_1Heads_4Flayers_32DModel_0.1Dropout will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9781
# No.1 Test Predictability: 0.0706
# No.1 Train Predictability: 0.0772
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0572
# No.2 Train Predictability: 0.0787
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0622
# No.3 Train Predictability: 0.0786
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.1108
# No.4 Train Predictability: 0.0967
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0457
# No.5 Train Predictability: 0.0656
# Predictability of Encoder_1nLayers_1Heads_4Flayers_32DModel_0.1Dropout: 0.0693
# Model Encoder_1nLayers_1Heads_4Flayers_32DModel_0.1Dropout backtest completed...
# ==================================================

# %%
'''close; ma12; mse'''
factor = pd.read_csv('../CSV/factor_ma12.csv')
input_dim = factor.shape[1] - 2
# print(f"Input dimension: {input_dim}")

label = pd.read_csv('../CSV/label_cleaned.csv')
# label.describe()
target = 3

# load data and model
Data = LoadData(factor, label, batch_size=32, num_workers=0, shuffle=True)
model_list = [
    LinearRegression(input_dim, target=target, model_name="LinearRegression"),
    ElasticNet(input_dim, target=target, alpha=0.5, l1_ratio=1, model_name="Lasso"),
    ElasticNet(input_dim, target=target, alpha=0.8, l1_ratio=0.5, model_name="ElasticNet"),
    RandomForest(n_estimators=100, target=target, max_depth=5, model_name="RandomForest"),
    XGBoost(target=target, n_estimators=100, max_depth=5, learning_rate=0.05, model_name="XGBoost"),
    CNN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, model_name="CNN"),
    NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, layer=1, model_name="NN"),
    NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, layer=2, model_name="NN"),
    NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, layer=3, model_name="NN"),
    NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, layer=4, model_name="NN"),
    NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, layer=5, model_name="NN"),
    K_Means_NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, n_clusters=10, layer=5, model_name="K_Means_NN"),
    Encoder(input_dim, target=target, nlayer=1, flayer=4, d_model=32, nhead=1, dropout=0.1, alpha=0.8, l1_ratio=0.5, model_name="Encoder")
]

# rolling test
count = 0
for model in model_list:
    RTT = RollingTrainTest(model, Data, train_size=0.5, test_size=0.1, epochs=20, patience=3, criterion=None, count=count)
    RTT.info(
        predictability_name = '[--ma12--|--close--|--mse--|--epochs=20--]'
        )
    RTT.run()
    RTT.backtest(trade_mode=1)
    count += 1
    print(f"Model {model.model_name} backtest completed...")
    print("=" * 50)
# Out:
# LinearRegression will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.1 Test Predictability: 0.1025
# No.1 Train Predictability: 0.0741
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0440
# No.2 Train Predictability: 0.0627
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0483
# No.3 Train Predictability: 0.0564
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0851
# No.4 Train Predictability: 0.0667
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0714
# No.5 Train Predictability: 0.0565
# Predictability of LinearRegression: 0.0703
# Model LinearRegression backtest completed...
# ==================================================
# Lasso will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.1 Test Predictability: 0.0200
# No.1 Train Predictability: 0.0193
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0072
# No.2 Train Predictability: 0.0067
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0025
# No.3 Train Predictability: 0.0023
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0009
# No.4 Train Predictability: 0.0014
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0156
# No.5 Train Predictability: 0.0147
# Predictability of Lasso: 0.0092
# Model Lasso backtest completed...
# ==================================================
# ElasticNet will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.1 Test Predictability: 0.0121
# No.1 Train Predictability: 0.0092
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0234
# No.2 Train Predictability: 0.0207
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0094
# No.3 Train Predictability: 0.0103
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0168
# No.4 Train Predictability: 0.0124
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0078
# No.5 Train Predictability: 0.0051
# Predictability of ElasticNet: 0.0139
# Model ElasticNet backtest completed...
# ==================================================
# RandomForest will run 5 iterations.
# No.1 Test Predictability: 0.0637
# No.1 Train Predictability: 0.0674
# No.2 Test Predictability: 0.0437
# No.2 Train Predictability: 0.0580
# No.3 Test Predictability: 0.0450
# No.3 Train Predictability: 0.0523
# No.4 Test Predictability: 0.0595
# No.4 Train Predictability: 0.0462
# No.5 Test Predictability: 0.0473
# No.5 Train Predictability: 0.0423
# Predictability of RandomForest: 0.0518
# Model RandomForest backtest completed...
# ==================================================
# XGBoost will run 5 iterations.
# No.1 Test Predictability: 0.0873
# No.1 Train Predictability: 0.0946
# No.2 Test Predictability: 0.0491
# No.2 Train Predictability: 0.0814
# No.3 Test Predictability: 0.0508
# No.3 Train Predictability: 0.0722
# No.4 Test Predictability: 0.0791
# No.4 Train Predictability: 0.0667
# No.5 Test Predictability: 0.0559
# No.5 Train Predictability: 0.0601
# Predictability of XGBoost: 0.0644
# Model XGBoost backtest completed...
# ==================================================
# CNN will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.1 Test Predictability: 0.0499
# No.1 Train Predictability: 0.0409
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0601
# No.2 Train Predictability: 0.0488
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0249
# No.3 Train Predictability: 0.0253
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0543
# No.4 Train Predictability: 0.0467
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0329
# No.5 Train Predictability: 0.0284
# Predictability of CNN: 0.0444
# Model CNN backtest completed...
# ==================================================
# NN_1Layers will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9794
# No.1 Test Predictability: 0.1021
# No.1 Train Predictability: 0.0893
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0273
# No.2 Train Predictability: 0.0504
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0548
# No.3 Train Predictability: 0.0658
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0848
# No.4 Train Predictability: 0.0655
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0631
# No.5 Train Predictability: 0.0585
# Predictability of NN_1Layers: 0.0664
# Model NN_1Layers backtest completed...
# ==================================================
# NN_2Layers will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9765
# No.1 Test Predictability: 0.0866
# No.1 Train Predictability: 0.0933
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0353
# No.2 Train Predictability: 0.0628
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0519
# No.3 Train Predictability: 0.0760
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0632
# No.4 Train Predictability: 0.0672
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0528
# No.5 Train Predictability: 0.0495
# Predictability of NN_2Layers: 0.0580
# Model NN_2Layers backtest completed...
# ==================================================
# NN_3Layers will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9737
# No.1 Test Predictability: 0.0955
# No.1 Train Predictability: 0.1071
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0274
# No.2 Train Predictability: 0.0721
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0622
# No.3 Train Predictability: 0.0845
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0620
# No.4 Train Predictability: 0.0587
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0536
# No.5 Train Predictability: 0.0635
# Predictability of NN_3Layers: 0.0601
# Model NN_3Layers backtest completed...
# ==================================================
# NN_4Layers will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9741
# No.1 Test Predictability: 0.0873
# No.1 Train Predictability: 0.0936
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0319
# No.2 Train Predictability: 0.0750
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0468
# No.3 Train Predictability: 0.0666
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0625
# No.4 Train Predictability: 0.0632
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0426
# No.5 Train Predictability: 0.0580
# Predictability of NN_4Layers: 0.0542
# Model NN_4Layers backtest completed...
# ==================================================
# NN_5Layers will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9744
# Epoch [20/20], Loss: 0.9689
# No.1 Test Predictability: 0.0641
# No.1 Train Predictability: 0.0766
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0387
# No.2 Train Predictability: 0.0817
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0269
# No.3 Train Predictability: 0.0587
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0751
# No.4 Train Predictability: 0.0703
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0622
# No.5 Train Predictability: 0.0772
# Predictability of NN_5Layers: 0.0534
# Model NN_5Layers backtest completed...
# ==================================================
# K_Means_NN_5Layers_10Clusters will run 5 iterations.
# K-means clustering completed:
#   Cluster 0: 14216 samples (8.9%)
#   Cluster 1: 8363 samples (5.2%)
#   Cluster 2: 15966 samples (10.0%)
#   Cluster 3: 25302 samples (15.8%)
#   Cluster 4: 19245 samples (12.0%)
#   Cluster 5: 7795 samples (4.9%)
#   Cluster 6: 36769 samples (23.0%)
#   Cluster 7: 11213 samples (7.0%)
#   Cluster 8: 16334 samples (10.2%)
#   Cluster 9: 4644 samples (2.9%)
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.1 Test Predictability: 0.0524
# No.1 Train Predictability: 0.0362
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0325
# No.2 Train Predictability: 0.0380
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0431
# No.3 Train Predictability: 0.0423
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0629
# No.4 Train Predictability: 0.0419
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0525
# No.5 Train Predictability: 0.0425
# Predictability of K_Means_NN_5Layers_10Clusters: 0.0487
# Model K_Means_NN_5Layers_10Clusters backtest completed...
# ==================================================
# Encoder_1nLayers_1Heads_4Flayers_32DModel_0.1Dropout will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9744
# Epoch [20/20], Loss: 0.9682
# No.1 Test Predictability: 0.0694
# No.1 Train Predictability: 0.0761
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0326
# No.2 Train Predictability: 0.0699
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0375
# No.3 Train Predictability: 0.0503
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0647
# No.4 Train Predictability: 0.0701
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0369
# No.5 Train Predictability: 0.0571
# Predictability of Encoder_1nLayers_1Heads_4Flayers_32DModel_0.1Dropout: 0.0482
# Model Encoder_1nLayers_1Heads_4Flayers_32DModel_0.1Dropout backtest completed...
# ==================================================

# %%
'''high; clean; mse'''
factor = pd.read_csv('../CSV/factor_cleaned.csv')
input_dim = factor.shape[1] - 2
# print(f"Input dimension: {input_dim}")

label = pd.read_csv('../CSV/label_cleaned.csv')
# label.describe()
target = 1

# load data and model
Data = LoadData(factor, label, batch_size=32, num_workers=0, shuffle=True)
model_list = [
    LinearRegression(input_dim, target=target, model_name="LinearRegression"),
    ElasticNet(input_dim, target=target, alpha=0.5, l1_ratio=1, model_name="Lasso"),
    ElasticNet(input_dim, target=target, alpha=0.8, l1_ratio=0.5, model_name="ElasticNet"),
    RandomForest(n_estimators=100, target=target, max_depth=5, model_name="RandomForest"),
    XGBoost(target=target, n_estimators=100, max_depth=5, learning_rate=0.05, model_name="XGBoost"),
    CNN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, model_name="CNN"),
    NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, layer=1, model_name="NN"),
    NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, layer=2, model_name="NN"),
    NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, layer=3, model_name="NN"),
    NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, layer=4, model_name="NN"),
    NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, layer=5, model_name="NN"),
    K_Means_NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, n_clusters=10, layer=5, model_name="K_Means_NN"),
    Encoder(input_dim, target=target, nlayer=1, flayer=4, d_model=32, nhead=1, dropout=0.1, alpha=0.8, l1_ratio=0.5, model_name="Encoder")
]

# rolling test
count = 0
for model in model_list:
    RTT = RollingTrainTest(model, Data, train_size=0.5, test_size=0.1, epochs=20, patience=3, criterion=None, count=count)
    RTT.info(
        predictability_name = '[--clean--|--high--|--mse--|--epochs=20--]'
        )
    RTT.run()
    RTT.backtest(trade_mode=2)
    count += 1
    print(f"Model {model.model_name} backtest completed...")
    print("=" * 50)
# Out:
# LinearRegression will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.1 Test Predictability: 0.0946
# No.1 Train Predictability: 0.1587
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0896
# No.2 Train Predictability: 0.1314
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.1160
# No.3 Train Predictability: 0.1459
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.1054
# No.4 Train Predictability: 0.1577
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.1430
# No.5 Train Predictability: 0.1396
# Predictability of LinearRegression: 0.1097
# Model LinearRegression backtest completed...
# ==================================================
# Lasso will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9731
# No.1 Test Predictability: 0.0646
# No.1 Train Predictability: 0.1052
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0901
# No.2 Train Predictability: 0.1253
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0885
# No.3 Train Predictability: 0.1080
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9830
# No.4 Test Predictability: 0.0881
# No.4 Train Predictability: 0.1255
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0974
# No.5 Train Predictability: 0.0961
# Predictability of Lasso: 0.0857
# Model Lasso backtest completed...
# ==================================================
# ElasticNet will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9714
# No.1 Test Predictability: 0.0801
# No.1 Train Predictability: 0.1265
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.1008
# No.2 Train Predictability: 0.1405
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.1127
# No.3 Train Predictability: 0.1380
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0885
# No.4 Train Predictability: 0.1226
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.1086
# No.5 Train Predictability: 0.0941
# Predictability of ElasticNet: 0.0981
# Model ElasticNet backtest completed...
# ==================================================
# RandomForest will run 5 iterations.
# No.1 Test Predictability: 0.1112
# No.1 Train Predictability: 0.1748
# No.2 Test Predictability: 0.1156
# No.2 Train Predictability: 0.1569
# No.3 Test Predictability: 0.1231
# No.3 Train Predictability: 0.1484
# No.4 Test Predictability: 0.1062
# No.4 Train Predictability: 0.1415
# No.5 Test Predictability: 0.1462
# No.5 Train Predictability: 0.1423
# Predictability of RandomForest: 0.1205
# Model RandomForest backtest completed...
# ==================================================
# XGBoost will run 5 iterations.
# No.1 Test Predictability: 0.1191
# No.1 Train Predictability: 0.2011
# No.2 Test Predictability: 0.1113
# No.2 Train Predictability: 0.1814
# No.3 Test Predictability: 0.1201
# No.3 Train Predictability: 0.1675
# No.4 Test Predictability: 0.1100
# No.4 Train Predictability: 0.1570
# No.5 Test Predictability: 0.1430
# No.5 Train Predictability: 0.1575
# Predictability of XGBoost: 0.1207
# Model XGBoost backtest completed...
# ==================================================
# CNN will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.1 Test Predictability: 0.0595
# No.1 Train Predictability: 0.0689
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0783
# No.2 Train Predictability: 0.0790
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0828
# No.3 Train Predictability: 0.0789
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0297
# No.4 Train Predictability: 0.0262
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0524
# No.5 Train Predictability: 0.0409
# Predictability of CNN: 0.0605
# Model CNN backtest completed...
# ==================================================
# NN_1Layers will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9136
# No.1 Test Predictability: 0.1142
# No.1 Train Predictability: 0.1830
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.1106
# No.2 Train Predictability: 0.1785
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0987
# No.3 Train Predictability: 0.1415
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.1053
# No.4 Train Predictability: 0.1464
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.1510
# No.5 Train Predictability: 0.1616
# Predictability of NN_1Layers: 0.1160
# Model NN_1Layers backtest completed...
# ==================================================
# NN_2Layers will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9082
# Epoch [20/20], Loss: 0.9012
# No.1 Test Predictability: 0.0995
# No.1 Train Predictability: 0.1591
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.1191
# No.2 Train Predictability: 0.2002
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0997
# No.3 Train Predictability: 0.1547
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0992
# No.4 Train Predictability: 0.1567
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.1543
# No.5 Train Predictability: 0.1796
# Predictability of NN_2Layers: 0.1144
# Model NN_2Layers backtest completed...
# ==================================================
# NN_3Layers will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9072
# Epoch [20/20], Loss: 0.9012
# No.1 Test Predictability: 0.1234
# No.1 Train Predictability: 0.1972
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.1058
# No.2 Train Predictability: 0.1764
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9224
# No.3 Test Predictability: 0.1000
# No.3 Train Predictability: 0.1579
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0959
# No.4 Train Predictability: 0.1472
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.1258
# No.5 Train Predictability: 0.1497
# Predictability of NN_3Layers: 0.1102
# Model NN_3Layers backtest completed...
# ==================================================
# NN_4Layers will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9077
# Epoch [20/20], Loss: 0.8999
# No.1 Test Predictability: 0.1078
# No.1 Train Predictability: 0.1724
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.1227
# No.2 Train Predictability: 0.2030
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9224
# No.3 Test Predictability: 0.1089
# No.3 Train Predictability: 0.1624
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.1007
# No.4 Train Predictability: 0.1701
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.1457
# No.5 Train Predictability: 0.1577
# Predictability of NN_4Layers: 0.1172
# Model NN_4Layers backtest completed...
# ==================================================
# NN_5Layers will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9072
# Epoch [20/20], Loss: 0.8996
# No.1 Test Predictability: 0.1194
# No.1 Train Predictability: 0.1970
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.1174
# No.2 Train Predictability: 0.1954
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.1269
# No.3 Train Predictability: 0.1878
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.1029
# No.4 Train Predictability: 0.1661
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.1536
# No.5 Train Predictability: 0.1852
# Predictability of NN_5Layers: 0.1240
# Model NN_5Layers backtest completed...
# ==================================================
# K_Means_NN_5Layers_10Clusters will run 5 iterations.
# K-means clustering completed:
#   Cluster 0: 24175 samples (15.1%)
#   Cluster 1: 4361 samples (2.7%)
#   Cluster 2: 16545 samples (10.4%)
#   Cluster 3: 13044 samples (8.2%)
#   Cluster 4: 17787 samples (11.1%)
#   Cluster 5: 7592 samples (4.7%)
#   Cluster 6: 6468 samples (4.0%)
#   Cluster 7: 47692 samples (29.8%)
#   Cluster 8: 13332 samples (8.3%)
#   Cluster 9: 8851 samples (5.5%)
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.1 Test Predictability: 0.1211
# No.1 Train Predictability: 0.1746
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.1177
# No.2 Train Predictability: 0.1592
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.1252
# No.3 Train Predictability: 0.1534
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.1093
# No.4 Train Predictability: 0.1411
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.1484
# No.5 Train Predictability: 0.1441
# Predictability of K_Means_NN_5Layers_10Clusters: 0.1243
# Model K_Means_NN_5Layers_10Clusters backtest completed...
# ==================================================
# Encoder_1nLayers_1Heads_4Flayers_32DModel_0.1Dropout will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9080
# Epoch [20/20], Loss: 0.9003
# No.1 Test Predictability: 0.1107
# No.1 Train Predictability: 0.1732
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9110
# No.2 Test Predictability: 0.0964
# No.2 Train Predictability: 0.1723
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.1111
# No.3 Train Predictability: 0.1661
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0978
# No.4 Train Predictability: 0.1486
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.1240
# No.5 Train Predictability: 0.1399
# Predictability of Encoder_1nLayers_1Heads_4Flayers_32DModel_0.1Dropout: 0.1080
# Model Encoder_1nLayers_1Heads_4Flayers_32DModel_0.1Dropout backtest completed...
# ==================================================

# %%
'''high; ma12; mse'''
factor = pd.read_csv('../CSV/factor_ma12.csv')
input_dim = factor.shape[1] - 2
# print(f"Input dimension: {input_dim}")

label = pd.read_csv('../CSV/label_cleaned.csv')
# label.describe()
target = 1

# load data and model
Data = LoadData(factor, label, batch_size=32, num_workers=0, shuffle=True)
model_list = [
    LinearRegression(input_dim, target=target, model_name="LinearRegression"),
    ElasticNet(input_dim, target=target, alpha=0.5, l1_ratio=1, model_name="Lasso"),
    ElasticNet(input_dim, target=target, alpha=0.8, l1_ratio=0.5, model_name="ElasticNet"),
    RandomForest(n_estimators=100, target=target, max_depth=5, model_name="RandomForest"),
    XGBoost(target=target, n_estimators=100, max_depth=5, learning_rate=0.05, model_name="XGBoost"),
    CNN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, model_name="CNN"),
    NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, layer=1, model_name="NN"),
    NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, layer=2, model_name="NN"),
    NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, layer=3, model_name="NN"),
    NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, layer=4, model_name="NN"),
    NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, layer=5, model_name="NN"),
    K_Means_NN(input_dim, target=target, alpha=0.8, l1_ratio=0.5, n_clusters=10, layer=5, model_name="K_Means_NN"),
    Encoder(input_dim, target=target, nlayer=1, flayer=4, d_model=32, nhead=1, dropout=0.1, alpha=0.8, l1_ratio=0.5, model_name="Encoder")
]

# rolling test
count = 0
for model in model_list:
    RTT = RollingTrainTest(model, Data, train_size=0.5, test_size=0.1, epochs=20, patience=3, criterion=None, count=count)
    RTT.info(
        predictability_name = '[--ma12--|--high--|--mse--|--epochs=20--]'
        )
    RTT.run()
    RTT.backtest(trade_mode=2)
    count += 1
    print(f"Model {model.model_name} backtest completed...")
    print("=" * 50)
# Out:
# LinearRegression will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.1 Test Predictability: 0.1140
# No.1 Train Predictability: 0.1581
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0682
# No.2 Train Predictability: 0.1330
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.1011
# No.3 Train Predictability: 0.1159
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0839
# No.4 Train Predictability: 0.1025
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.1103
# No.5 Train Predictability: 0.1189
# Predictability of LinearRegression: 0.0955
# Model LinearRegression backtest completed...
# ==================================================
# Lasso will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9872
# No.1 Test Predictability: 0.0723
# No.1 Train Predictability: 0.1239
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0580
# No.2 Train Predictability: 0.0899
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0880
# No.3 Train Predictability: 0.1025
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0743
# No.4 Train Predictability: 0.0879
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.1039
# No.5 Train Predictability: 0.1184
# Predictability of Lasso: 0.0793
# Model Lasso backtest completed...
# ==================================================
# ElasticNet will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9833
# No.1 Test Predictability: 0.1030
# No.1 Train Predictability: 0.1332
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0590
# No.2 Train Predictability: 0.0936
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0962
# No.3 Train Predictability: 0.1110
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0846
# No.4 Train Predictability: 0.1114
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0852
# No.5 Train Predictability: 0.0914
# Predictability of ElasticNet: 0.0856
# Model ElasticNet backtest completed...
# ==================================================
# RandomForest will run 5 iterations.
# No.1 Test Predictability: 0.0975
# No.1 Train Predictability: 0.1436
# No.2 Test Predictability: 0.0748
# No.2 Train Predictability: 0.1278
# No.3 Test Predictability: 0.0952
# No.3 Train Predictability: 0.1188
# No.4 Test Predictability: 0.0877
# No.4 Train Predictability: 0.1160
# No.5 Test Predictability: 0.0993
# No.5 Train Predictability: 0.1177
# Predictability of RandomForest: 0.0909
# Model RandomForest backtest completed...
# ==================================================
# XGBoost will run 5 iterations.
# No.1 Test Predictability: 0.1148
# No.1 Train Predictability: 0.1697
# No.2 Test Predictability: 0.0761
# No.2 Train Predictability: 0.1508
# No.3 Test Predictability: 0.0989
# No.3 Train Predictability: 0.1403
# No.4 Test Predictability: 0.0969
# No.4 Train Predictability: 0.1337
# No.5 Test Predictability: 0.0974
# No.5 Train Predictability: 0.1341
# Predictability of XGBoost: 0.0968
# Model XGBoost backtest completed...
# ==================================================
# CNN will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.1 Test Predictability: 0.0593
# No.1 Train Predictability: 0.0490
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0861
# No.2 Train Predictability: 0.0670
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0547
# No.3 Train Predictability: 0.0507
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0366
# No.4 Train Predictability: 0.0303
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0523
# No.5 Train Predictability: 0.0433
# Predictability of CNN: 0.0578
# Model CNN backtest completed...
# ==================================================
# NN_1Layers will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9340
# No.1 Test Predictability: 0.1322
# No.1 Train Predictability: 0.1795
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.1042
# No.2 Train Predictability: 0.1707
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9482
# No.3 Test Predictability: 0.1009
# No.3 Train Predictability: 0.1382
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0953
# No.4 Train Predictability: 0.1334
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.1007
# No.5 Train Predictability: 0.1300
# Predictability of NN_1Layers: 0.1067
# Model NN_1Layers backtest completed...
# ==================================================
# NN_2Layers will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9309
# Epoch [20/20], Loss: 0.9252
# No.1 Test Predictability: 0.1132
# No.1 Train Predictability: 0.1662
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0604
# No.2 Train Predictability: 0.1375
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.1054
# No.3 Train Predictability: 0.1429
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0865
# No.4 Train Predictability: 0.1319
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0962
# No.5 Train Predictability: 0.1334
# Predictability of NN_2Layers: 0.0923
# Model NN_2Layers backtest completed...
# ==================================================
# NN_3Layers will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9298
# No.1 Test Predictability: 0.1109
# No.1 Train Predictability: 0.1583
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9351
# No.2 Test Predictability: 0.0786
# No.2 Train Predictability: 0.1447
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0989
# No.3 Train Predictability: 0.1459
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0997
# No.4 Train Predictability: 0.1551
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0972
# No.5 Train Predictability: 0.1379
# Predictability of NN_3Layers: 0.0971
# Model NN_3Layers backtest completed...
# ==================================================
# NN_4Layers will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9299
# Epoch [20/20], Loss: 0.9247
# No.1 Test Predictability: 0.1153
# No.1 Train Predictability: 0.1615
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9337
# No.2 Test Predictability: 0.0786
# No.2 Train Predictability: 0.1540
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.1021
# No.3 Train Predictability: 0.1500
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0966
# No.4 Train Predictability: 0.1378
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0921
# No.5 Train Predictability: 0.1322
# Predictability of NN_4Layers: 0.0969
# Model NN_4Layers backtest completed...
# ==================================================
# NN_5Layers will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9307
# Epoch [20/20], Loss: 0.9249
# No.1 Test Predictability: 0.1052
# No.1 Train Predictability: 0.1591
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9345
# No.2 Test Predictability: 0.0973
# No.2 Train Predictability: 0.1762
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.1009
# No.3 Train Predictability: 0.1474
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.1012
# No.4 Train Predictability: 0.1491
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0758
# No.5 Train Predictability: 0.1161
# Predictability of NN_5Layers: 0.0961
# Model NN_5Layers backtest completed...
# ==================================================
# K_Means_NN_5Layers_10Clusters will run 5 iterations.
# K-means clustering completed:
#   Cluster 0: 16334 samples (10.2%)
#   Cluster 1: 15966 samples (10.0%)
#   Cluster 2: 19245 samples (12.0%)
#   Cluster 3: 7795 samples (4.9%)
#   Cluster 4: 11213 samples (7.0%)
#   Cluster 5: 14216 samples (8.9%)
#   Cluster 6: 8363 samples (5.2%)
#   Cluster 7: 25302 samples (15.8%)
#   Cluster 8: 4644 samples (2.9%)
#   Cluster 9: 36769 samples (23.0%)
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.1 Test Predictability: 0.0919
# No.1 Train Predictability: 0.1143
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0689
# No.2 Train Predictability: 0.1152
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0980
# No.3 Train Predictability: 0.1121
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0893
# No.4 Train Predictability: 0.1077
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.0953
# No.5 Train Predictability: 0.1065
# Predictability of K_Means_NN_5Layers_10Clusters: 0.0887
# Model K_Means_NN_5Layers_10Clusters backtest completed...
# ==================================================
# Encoder_1nLayers_1Heads_4Flayers_32DModel_0.1Dropout will run 5 iterations.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch [10/20], Loss: 0.9322
# No.1 Test Predictability: 0.1190
# No.1 Train Predictability: 0.1731
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.2 Test Predictability: 0.0777
# No.2 Train Predictability: 0.1530
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.3 Test Predictability: 0.0828
# No.3 Train Predictability: 0.1333
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.4 Test Predictability: 0.0806
# No.4 Train Predictability: 0.1143
#   0%|          | 0/20 [00:00<?, ?it/s]
# No.5 Test Predictability: 0.1006
# No.5 Train Predictability: 0.1463
# Predictability of Encoder_1nLayers_1Heads_4Flayers_32DModel_0.1Dropout: 0.0921
# Model Encoder_1nLayers_1Heads_4Flayers_32DModel_0.1Dropout backtest completed...
# ==================================================
