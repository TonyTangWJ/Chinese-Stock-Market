# %% [markdown]
# **1.数据加载时进一步去除异常值,保留0.1~0.9**

# %% [markdown]
# **2.用了弹性网后,预测力降低,盈利能力提高**\
# elastic_net 能够让模型结果更多的趋向于负数,提高风险识别.\
# 尽管某些股票的次月收益率为正,但模型预测仍然为负值,所以会导致预测力降低.\
# 但由于中国股市的风险更高,模型更注重风险,其收益率会展现更高.

# %% [markdown]
# **3.相关系数较低的因子形成交互项,有利于收益率的提高**

# %% [markdown]
# **4.增加0.01反相关系数,能够增强非线性模型的表现(mse_loss)**

# %% [markdown]
# **5.预测最高价,效果很好**
