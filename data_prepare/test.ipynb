# %%
import tushare as ts
import pandas as pd
import numpy as np
from sql import sql
from tqdm.auto import tqdm
from prepare_data import prepare_data, data_engineering
import warnings
from datetime import datetime, timedelta
warnings.simplefilter(action='ignore', category=FutureWarning)
main = prepare_data()

# %%
a = data_engineering()
# b = a.moving_average(window=12, cover_data=False)
# Out:
# Cleaned data not found, loading raw data and cleaning...
# Cleaned data saved to CSV files.
