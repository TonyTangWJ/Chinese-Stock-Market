# %%
import tushare as ts
import pandas as pd
import numpy as np
from sql import sql
from tqdm.auto import tqdm
from prepare_data import prepare_data, data_engineering
import warnings
from datetime import datetime, timedelta
warnings.simplefilter(action='ignore', category=FutureWarning)
main = prepare_data()

# %%
a = data_engineering()
a.create_comprehensive_factors()
# Out:
# 开始因子工程，原始因子数量: 62
# 添加6期滚动平均因子...
# 添加12期滚动平均因子...
# 添加24期滚动平均因子...
# 添加波动性因子...
# 添加动量因子...
# 处理数值精度，保留4位小数...
# 最终数据质量检查...
# Enhanced Factor NaN count: 0
# Enhanced Label NaN count: 0
# 因子工程完成，最终因子数量: 372
# 新增因子数量: 310
#
# 数据精度示例:
# trade_date: [201501 201502 201503]
# assets_to_eqt: [4.9  4.9  4.39]
# bps: [7.13 7.13 7.99]
# 保存数据...
# 增强因子数据已保存到 '../CSV/enhanced_factor.csv'
# (          ts_code  trade_date  assets_to_eqt   bps  ca_to_assets  cfps  \
#  0       000002.SZ      201501           4.90  7.13         91.72  0.44
#  1       000002.SZ      201502           4.90  7.13         91.72  0.44
#  2       000002.SZ      201503           4.39  7.99         91.42  1.69
#  3       000002.SZ      201504           4.53  8.05         91.48 -2.14
#  4       000002.SZ      201505           4.53  8.05         91.48 -2.14
#  ...           ...         ...            ...   ...           ...   ...
#  324750  605599.SH      202408           1.78  4.70         94.50 -0.23
#  324751  605599.SH      202409           1.78  4.70         94.50 -0.23
#  324752  605599.SH      202410           1.79  4.92         94.12 -0.01
#  324753  605599.SH      202411           1.79  4.92         94.12 -0.01
#  324754  605599.SH      202412           1.79  4.92         94.12 -0.01
#
#          current_ratio  currentdebt_to_debt  debt_to_assets  \
#  0                1.34                86.06           79.58
#  1                1.34                86.06           79.58
#  2                1.34                88.06           77.20
#  3                1.30                90.11           77.91
#  4                1.30                90.11           77.91
#  ...               ...                  ...             ...
#  324750           2.26                95.40           43.90
#  324751           2.26                95.40           43.90
#  324752           2.25                94.77           44.05
#  324753           2.25                94.77           44.05
#  324754           2.25                94.77           44.05
#
#          dtprofit_to_profit  ...  stk_div_mom5  cash_div_tax_mom5  \
#  0                    96.05  ...           0.0             0.0000
#  1                    96.05  ...           0.0             0.0000
#  2                    98.93  ...           0.0             0.0000
#  3                    96.68  ...           0.0             0.0000
#  4                    96.68  ...           0.0             0.0000
#  ...                    ...  ...           ...                ...
#  324750               96.46  ...          -1.0             0.5217
#  324751               96.46  ...          -1.0             0.5217
#  324752               94.69  ...          -1.0             0.5217
#  324753               94.69  ...          -1.0             0.0000
#  324754               94.69  ...          -1.0             0.0000
#
#          total_mv_mom5  turnover_rate_mom5  volume_ratio_mom5  pb_mom5  \
#  0              0.0000              0.0000             0.0000   0.0000
#  1              0.0000              0.0000             0.0000   0.0000
#  2              0.0000              0.0000             0.0000   0.0000
#  3              0.0000              0.0000             0.0000   0.0000
#  4              0.0000              0.0000             0.0000   0.0000
#  ...               ...                 ...                ...      ...
#  324750        -0.1052             -0.3974             0.0642  -0.0755
#  324751        -0.2411             -0.3855             0.1262  -0.2413
#  324752        -0.2743             -0.2727            -0.0818  -0.2762
#  324753        -0.2573              0.1186             0.0729  -0.2077
#  324754        -0.1283              0.3273            -0.0100  -0.1818
#
#          pe_ttm_mom5  ps_ttm_mom5  dv_ttm_mom5  pcf_mom5
#  0            0.0000       0.0000       0.0000    0.0000
#  1            0.0000       0.0000       0.0000    0.0000
#  2            0.0000       0.0000       0.0000    0.0000
#  3            0.0000       0.0000       0.0000    0.0000
#  4            0.0000       0.0000       0.0000    0.0000
#  ...             ...          ...          ...       ...
#  324750      -0.1622      -0.2615       0.6954   -0.3363
#  324751      -0.2403      -0.4143       1.0087   -0.4370
#  324752      -0.2628      -0.4286       1.0939   -1.0000
#  324753      -0.1735      -0.3231       1.0485   -1.0000
#  324754      -0.0305      -0.2069       0.0741   -1.0000
#
#  [324755 rows x 374 columns],
#            ts_code  trade_date  highest_return  lowest_return  close_return
#  0       000002.SZ      201501           10.07         -13.26         -5.62
#  1       000002.SZ      201502            3.15         -10.45         -2.81
#  2       000002.SZ      201503           17.46          -9.60          8.44
#  3       000002.SZ      201504           10.34          -4.58          5.65
#  4       000002.SZ      201505            8.68          -8.17         -1.72
#  ...           ...         ...             ...            ...           ...
#  324750  605599.SH      202408            0.96         -10.27         -6.53
#  324751  605599.SH      202409           11.55         -10.80         10.71
#  324752  605599.SH      202410            9.84         -11.94        -10.43
#  324753  605599.SH      202411            8.64          -1.50          7.98
#  324754  605599.SH      202412            5.65          -4.09         -1.30
#
#  [324755 rows x 5 columns])
