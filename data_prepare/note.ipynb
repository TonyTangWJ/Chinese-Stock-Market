# %% [markdown]
# **1. factor数据保持在 0.04~0.96**\
# **2. 月度收益率保持在 -0.2~0.2**\
# **3. 月度最高收益率保持在 0~0.3**\
# **4. 月度最低收益率保持在 -0.3~0**

# %% [markdown]
# **5.制造交互项,根据相关系数**\
# 5.1 相关系数>=0.5\
# 5.2 相关系数<=0.1\
# 5.3 相关系数<=0.01\
# 5.4 相关系数<=0.001\
# 5.5 相关系数<=0.0001
