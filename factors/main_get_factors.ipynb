# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from database.get_data import get_data
import get_factors
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# initialization
main = get_data()

# %%
import sys
for p in sys.path:
    print(p)
# Out:
# e:\Anaconda\envs\ChineseStockMarket\python312.zip
# e:\Anaconda\envs\ChineseStockMarket\DLLs
# e:\Anaconda\envs\ChineseStockMarket\Lib
# e:\Anaconda\envs\ChineseStockMarket
#
# e:\Anaconda\envs\ChineseStockMarket\Lib\site-packages
# e:\Anaconda\envs\ChineseStockMarket\Lib\site-packages\win32
# e:\Anaconda\envs\ChineseStockMarket\Lib\site-packages\win32\lib
# e:\Anaconda\envs\ChineseStockMarket\Lib\site-packages\Pythonwin
