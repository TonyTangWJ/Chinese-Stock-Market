# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from matplotlib.colors import LinearSegmentedColormap
from matplotlib.lines import Line2D

# %%
# 从CSV文件读取数据
df = pd.read_csv('../CSV_results/predictability_visualize.csv', index_col=0)

# 创建图表
plt.figure(figsize=(14, 8))

# 设置位置
x_pos = np.arange(len(df.index))

# 绘制点 - 仅用形状区分
plt.scatter(x_pos, df['O-Data & Close'], facecolors='none', edgecolors='black', marker='o', s=50, label='O-Data & Close', zorder=5)  # 空心圆
plt.scatter(x_pos, df['T-Data & Close'], color='black', marker='D', s=50, label='T-Data & Close', zorder=5)  # 实心菱形

# 绘制连接线（从O-Data指向T-Data）
for i, model in enumerate(df.index):
    o_val = df.loc[model, 'O-Data & Close']
    t_val = df.loc[model, 'T-Data & Close']
    
    # 确定线段颜色
    if t_val > o_val:  # 数值上升
        color = 'red'
    else:  # 数值下降
        color = 'green'
    
    # 绘制带箭头的线段（从O-Data指向T-Data）
    plt.annotate('', 
                 xy=(i, t_val),          # 箭头终点（T-Data）
                 xytext=(i, o_val),      # 箭头起点（O-Data）
                 arrowprops=dict(arrowstyle='->', 
                                color=color, 
                                lw=2,
                                shrinkA=5,  # 箭头起点缩进
                                shrinkB=5)  # 箭头终点缩进
                )

# 设置图表属性
plt.xlabel('Models', fontsize=12, fontweight='bold')
plt.ylabel('Predictability (%)', fontsize=12, fontweight='bold')
plt.title('Model Predictability Comparison: O-Data vs T-Data (Close)\n(Arrows show direction from O-Data to T-Data)', 
          fontsize=14, fontweight='bold')
plt.xticks(x_pos, df.index, rotation=45, ha='right')
plt.legend()

# 去掉三边的边框
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['left'].set_visible(False)

# 调整布局
plt.tight_layout()

# 创建image文件夹如果不存在
os.makedirs('../image', exist_ok=True)

# 保存图片到image文件夹
plt.savefig('../image/model_predictability_close.svg', bbox_inches='tight')

# 显示图表
plt.show()

# %%
# 从CSV文件读取数据
df = pd.read_csv('../CSV_results/predictability_visualize.csv', index_col=0)

# 创建图表
plt.figure(figsize=(14, 8))

# 设置位置
x_pos = np.arange(len(df.index))

# 绘制点 - 仅用形状区分
plt.scatter(x_pos, df['O-Data & High'], facecolors='none', edgecolors='black', marker='o', s=50, label='O-Data & High', zorder=5)  # 空心圆
plt.scatter(x_pos, df['T-Data & High'], color='black', marker='D', s=50, label='T-Data & High', zorder=5)  # 实心菱形

# 绘制连接线（从O-Data指向T-Data）
for i, model in enumerate(df.index):
    o_val = df.loc[model, 'O-Data & High']
    t_val = df.loc[model, 'T-Data & High']
    
    # 确定线段颜色
    if t_val > o_val:  # 数值上升
        color = 'red'
    else:  # 数值下降
        color = 'green'
    
    # 绘制带箭头的线段（从O-Data指向T-Data）
    plt.annotate('', 
                 xy=(i, t_val),          # 箭头终点（T-Data）
                 xytext=(i, o_val),      # 箭头起点（O-Data）
                 arrowprops=dict(arrowstyle='->', 
                                color=color, 
                                lw=2,
                                shrinkA=5,  # 箭头起点缩进
                                shrinkB=5)  # 箭头终点缩进
                )

# 设置图表属性
plt.xlabel('Models', fontsize=12, fontweight='bold')
plt.ylabel('Predictability (%)', fontsize=12, fontweight='bold')
plt.title('Model Predictability Comparison: O-Data vs T-Data (High)\n(Arrows show direction from O-Data to T-Data)', 
          fontsize=14, fontweight='bold')
plt.xticks(x_pos, df.index, rotation=45, ha='right')
plt.legend()

# 去掉三边的边框
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['left'].set_visible(False)

# 调整布局
plt.tight_layout()

# 创建image文件夹如果不存在
os.makedirs('../image', exist_ok=True)

# 保存图片到image文件夹
plt.savefig('../image/model_predictability_high.svg', bbox_inches='tight')

# 显示图表
plt.show()

# %%
# 从CSV文件读取数据
df = pd.read_csv('../CSV_results/predictability_visualize.csv', index_col=0)

# 创建图表
plt.figure(figsize=(14, 8))

# 设置位置
x_pos = np.arange(len(df.index))

# 绘制点 - 仅用形状区分
plt.scatter(x_pos, df['O-Data & Close'], facecolors='none', edgecolors='black', marker='s', s=50, label='O-Data & Close', zorder=5)  # 空心方形
plt.scatter(x_pos, df['O-Data & High'], color='black', marker='^', s=50, label='O-Data & High', zorder=5)  # 实心三角形

# 绘制连接线（从Close指向High）
for i, model in enumerate(df.index):
    close_val = df.loc[model, 'O-Data & Close']
    high_val = df.loc[model, 'O-Data & High']
    
    # 确定线段颜色
    if high_val > close_val:  # High值大于Close值
        color = 'red'
    else:  # High值小于Close值
        color = 'green'
    
    # 绘制带箭头的线段（从Close指向High）
    plt.annotate('', 
                 xy=(i, high_val),          # 箭头终点（High）
                 xytext=(i, close_val),     # 箭头起点（Close）
                 arrowprops=dict(arrowstyle='->', 
                                color=color, 
                                lw=2,
                                shrinkA=5,  # 箭头起点缩进
                                shrinkB=5)  # 箭头终点缩进
                )

# 设置图表属性
plt.xlabel('Models', fontsize=12, fontweight='bold')
plt.ylabel('Predictability (%)', fontsize=12, fontweight='bold')
plt.title('Model Predictability Comparison: Close vs High (O-Data)\n(Arrows show direction from Close to High)', 
          fontsize=14, fontweight='bold')
plt.xticks(x_pos, df.index, rotation=45, ha='right')
plt.legend()

# 去掉三边的边框
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['left'].set_visible(False)

# 调整布局
plt.tight_layout()

# 创建image文件夹如果不存在
os.makedirs('../image', exist_ok=True)

# 保存图片到image文件夹
plt.savefig('../image/model_predictability_O-data.svg', bbox_inches='tight')

# 显示图表
plt.show()

# %%
# 从CSV文件读取数据
df = pd.read_csv('../CSV_results/predictability_visualize.csv', index_col=0)

# 创建图表
plt.figure(figsize=(14, 8))

# 设置位置
x_pos = np.arange(len(df.index))

# 绘制点 - 仅用形状区分
plt.scatter(x_pos, df['T-Data & Close'], facecolors='none', edgecolors='black', marker='s', s=50, label='T-Data & Close', zorder=5)  # 空心方形
plt.scatter(x_pos, df['T-Data & High'], color='black', marker='^', s=50, label='T-Data & High', zorder=5)  # 实心三角形

# 绘制连接线（从Close指向High）
for i, model in enumerate(df.index):
    close_val = df.loc[model, 'T-Data & Close']
    high_val = df.loc[model, 'T-Data & High']
    
    # 确定线段颜色
    if high_val > close_val:  # High值大于Close值
        color = 'red'
    else:  # High值小于Close值
        color = 'green'
    
    # 绘制带箭头的线段（从Close指向High）
    plt.annotate('', 
                 xy=(i, high_val),          # 箭头终点（High）
                 xytext=(i, close_val),     # 箭头起点（Close）
                 arrowprops=dict(arrowstyle='->', 
                                color=color, 
                                lw=2,
                                shrinkA=5,  # 箭头起点缩进
                                shrinkB=5)  # 箭头终点缩进
                )

# 设置图表属性
plt.xlabel('Models', fontsize=12, fontweight='bold')
plt.ylabel('Predictability (%)', fontsize=12, fontweight='bold')
plt.title('Model Predictability Comparison: Close vs High (T-Data)\n(Arrows show direction from Close to High)', 
          fontsize=14, fontweight='bold')
plt.xticks(x_pos, df.index, rotation=45, ha='right')
plt.legend()

# 去掉三边的边框
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['left'].set_visible(False)

# 调整布局
plt.tight_layout()

# 创建image文件夹如果不存在
os.makedirs('../image', exist_ok=True)

# 保存图片到image文件夹
plt.savefig('../image/model_predictability_T-data.svg', bbox_inches='tight')

# 显示图表
plt.show()

# %%
# 从CSV文件读取数据
df = pd.read_csv('../CSV_results/predictability_rank_visualize.csv', index_col=0)

# 创建图表
plt.figure(figsize=(14, 8))

# 设置位置
x_pos = np.arange(len(df.index))

# 定义四种数据类别的标记和颜色
markers = ['o', 's', '^', 'D']  # 圆形、方形、三角形、菱形
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']  # 更鲜明的颜色
categories = df.columns.tolist()


# 为每种数据类别绘制散点图
for i, category in enumerate(categories):
    plt.scatter(x_pos, df[category], 
                marker=markers[i], 
                color=colors[i], 
                s=120, 
                label=category,
                alpha=0.9,
                edgecolors='white',
                linewidth=1.5,
                zorder=5)

# 设置图表属性
min_rank = df.values.min()
max_rank = df.values.max()
y_ticks = np.arange(min_rank, max_rank + 1)
plt.yticks(y_ticks)
plt.xlabel('Models', fontsize=12, fontweight='bold')
plt.ylabel('Rank of Models', fontsize=12, fontweight='bold')
plt.title('Model Predictability Rankings: Comparison Across 4 Datasets', 
          fontsize=14, fontweight='bold')
plt.xticks(x_pos, df.index, rotation=45, ha='right')

# 添加图例
plt.legend()

# 添加网格线
plt.grid(True, alpha=0.2, axis='y')

# 反转y轴，因为排名1是最好的
plt.gca().invert_yaxis()

# 美化边框
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['left'].set_alpha(False)

# 调整布局
plt.tight_layout()

# 创建image文件夹如果不存在
os.makedirs('../image', exist_ok=True)

# 保存图片
plt.savefig('../image/model_predictability_rank.svg', bbox_inches='tight')

# 显示图表
plt.show()

# %%
# 从CSV文件读取数据
df = pd.read_csv('../CSV_results/predictability_visualize.csv', index_col=0)

# 按AVG_RANK排序，便于观察
df_sorted = df.sort_values('AVG_RANK')

# 创建画布和子图
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

# 设置统一的色阶
vmin = df_sorted['AVG_VALUE'].min()
vmax = df_sorted['AVG_VALUE'].max()
norm = plt.Normalize(vmin, vmax)

# 创建从红色（高）到绿色（低）的自定义颜色映射
colors = ['green', 'yellow', 'red']  # 低到高：绿→黄→红
cmap = LinearSegmentedColormap.from_list('red_green', colors, N=100)

# 子图1：柱状图 - AVG_VALUE（使用统一色阶）
bars = ax1.bar(range(len(df_sorted)), df_sorted['AVG_VALUE'], 
               color=cmap(norm(df_sorted['AVG_VALUE'])),
               alpha=0.8, edgecolor='black', linewidth=1)

# 在柱子上添加数值标签
for i, (model, value) in enumerate(zip(df_sorted.index, df_sorted['AVG_VALUE'])):
    ax1.text(i, value + 0.1, f'{value:.2f}', ha='center', va='bottom', 
             fontweight='bold', fontsize=9)

ax1.set_xlabel('Models', fontsize=12, fontweight='bold')
ax1.set_ylabel('Average Predictability', fontsize=12, fontweight='bold')
ax1.set_title('Average Predictability of Each Model\n(Red = High, Green = Low)', 
              fontsize=14, fontweight='bold')
ax1.set_xticks(range(len(df_sorted)))
ax1.set_xticklabels(df_sorted.index, rotation=45, ha='right')
ax1.set_ylim(0, df_sorted['AVG_VALUE'].max() + 1)
ax1.grid(True, alpha=0.3, axis='y')

# 子图2：散点图 + 详细标注 - AVG_RANK（使用统一色阶）
scatter = ax2.scatter(range(len(df_sorted)), df_sorted['AVG_RANK'], 
                     s=200, c=df_sorted['AVG_VALUE'], 
                     cmap=cmap, norm=norm, alpha=0.8, 
                     edgecolors='black', linewidth=1.5)

# 添加详细标注
for i, (model, rank, value) in enumerate(zip(df_sorted.index, df_sorted['AVG_RANK'], df_sorted['AVG_VALUE'])):
    ax2.annotate(f'{model}\nRank: {rank}\nValue: {value:.2f}%', 
                xy=(i, rank),
                xytext=(10, 15),
                textcoords='offset points',
                fontsize=8,
                bbox=dict(boxstyle='round,pad=0.3', facecolor='lightblue', alpha=0.7),
                arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=0', color='gray'))

ax2.set_xlabel('Models', fontsize=12, fontweight='bold')
ax2.set_ylabel('Average Rankings', fontsize=12, fontweight='bold')
ax2.set_title('Model Rankings with Predictability Values\n(Red = High, Green = Low)', 
              fontsize=14, fontweight='bold')
ax2.set_xticks(range(len(df_sorted)))
ax2.set_xticklabels(df_sorted.index, rotation=45, ha='right')
ax2.set_ylim(0, df_sorted['AVG_RANK'].max() + 1)
ax2.grid(True, alpha=0.3)
ax2.invert_yaxis()  

# 添加统一的颜色条（放在两个子图右侧）
cbar = plt.colorbar(scatter, ax=ax2)
cbar.set_label('Predictability Value (%)\n(Red = High, Green = Low)', fontsize=10)

plt.tight_layout()

# 创建image文件夹如果不存在
os.makedirs('../image', exist_ok=True)

# 保存图片
plt.savefig('../image/predictability_value_vs_rank.svg', bbox_inches='tight')

plt.show()

# %%
# 读取CSV文件
df = pd.read_csv('../CSV_results/profit_visualize.csv')

# 分别提取O-Data & Close和T-Data & Close的数据
df_o = df[df['Datasets'] == 'O-Data & Close'].set_index('Model')
df_t = df[df['Datasets'] == 'T-Data & Close'].set_index('Model')

# 创建2行3列的子图画布
fig, axes = plt.subplots(2, 3, figsize=(28, 16))

# 定义要展示的6个收益指标及其排列顺序
metrics_row1 = ['AvR', 'S.R.', 'AnR']  # 第一行指标
metrics_row2 = ['Std', 'AnV', 'Max DD']  # 第二行指标
titles = {
    'AvR': 'Average Return', 
    'S.R.': 'Sharpe Ratio', 
    'Std': 'Standard Deviation',
    'AnR': 'Annualized Return', 
    'AnV': 'Annualized Volatility', 
    'Max DD': 'Maximum Drawdown'
}

# 设置位置
x_pos = np.arange(len(df_o))

# 遍历第一行的3个指标
for i, metric in enumerate(metrics_row1):
    ax = axes[0, i]  # 第一行的第i个子图
    
    # 获取O-Data和T-Data的指标值
    o_vals = df_o[metric].values
    t_vals = df_t[metric].values
    
    # 绘制散点图：O-Data用空心方形，T-Data用实心三角形
    ax.scatter(x_pos, o_vals, facecolors='none', edgecolors='black', marker='o', s=50, label='O-Data', zorder=5)
    ax.scatter(x_pos, t_vals, color='black', marker='D', s=50, label='T-Data', zorder=5)
    
    # 绘制连接线（从O-Data指向T-Data）
    for j, model in enumerate(df_o.index):
        o_val = o_vals[j]
        t_val = t_vals[j]
        
        # 确定线段颜色：红色表示变好（T-Data > O-Data），绿色表示变差
        color = 'red' if t_val > o_val else 'green'
        
        # 绘制带箭头的线段
        ax.annotate('', 
                   xy=(j, t_val),          # 箭头终点（T-Data）
                   xytext=(j, o_val),      # 箭头起点（O-Data）
                   arrowprops=dict(arrowstyle='->', 
                                  color=color, 
                                  lw=2,
                                  shrinkA=5,  # 箭头起点缩进
                                  shrinkB=5)  # 箭头终点缩进
                  )
    
    # 设置子图属性
    ax.set_xlabel('Models', fontsize=10, fontweight='bold')
    ax.set_ylabel(metric, fontsize=10, fontweight='bold')
    ax.set_title(titles[metric], fontsize=12, fontweight='bold')
    ax.set_xticks(x_pos)
    ax.set_xticklabels(df_o.index, rotation=45, ha='right')
    ax.legend()
    # 去掉三边的边框
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)

# 遍历第二行的3个指标（值越小越好的指标）
for i, metric in enumerate(metrics_row2):
    ax = axes[1, i]  # 第二行的第i个子图
    
    # 获取O-Data和T-Data的指标值
    o_vals = df_o[metric].values
    t_vals = df_t[metric].values
    
    # 绘制散点图
    ax.scatter(x_pos, o_vals, facecolors='none', edgecolors='black', marker='o', s=50, label='O-Data', zorder=5)
    ax.scatter(x_pos, t_vals, color='black', marker='D', s=50, label='T-Data', zorder=5)

    # 绘制连接线（从O-Data指向T-Data）
    for j, model in enumerate(df_o.index):
        o_val = o_vals[j]
        t_val = t_vals[j]
        
        # 确定线段颜色：对于值越小越好的指标，红色表示变好（T-Data < O-Data），绿色表示变差
        color = 'red' if t_val < o_val else 'green'
        
        # 绘制带箭头的线段
        ax.annotate('', 
                   xy=(j, t_val),          # 箭头终点（T-Data）
                   xytext=(j, o_val),      # 箭头起点（O-Data）
                   arrowprops=dict(arrowstyle='->', 
                                  color=color, 
                                  lw=2,
                                  shrinkA=5,  # 箭头起点缩进
                                  shrinkB=5)  # 箭头终点缩进
                  )
    
    # 设置子图属性
    ax.set_xlabel('Models', fontsize=10, fontweight='bold')
    ax.set_ylabel(metric, fontsize=10, fontweight='bold')
    ax.set_title(titles[metric], fontsize=12, fontweight='bold')
    ax.set_xticks(x_pos)
    ax.set_xticklabels(df_o.index, rotation=45, ha='right')
    ax.legend()
    # 去掉三边的边框
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)

# 调整布局
plt.tight_layout()

# 创建image文件夹如果不存在
os.makedirs('../image', exist_ok=True)

# 保存图片为SVG格式
plt.savefig('../image/model_profit_close.svg', bbox_inches='tight')

# 显示图表
plt.show()

# %%
# 读取CSV文件
df = pd.read_csv('../CSV_results/profit_visualize.csv')

# 分别提取O-Data & High和T-Data & High的数据，并排除RF和XGB模型
df_o = df[(df['Datasets'] == 'O-Data & High') & (~df['Model'].isin(['RF', 'XGB']))].set_index('Model')
df_t = df[(df['Datasets'] == 'T-Data & High') & (~df['Model'].isin(['RF', 'XGB']))].set_index('Model')

# 创建2行3列的子图画布
fig, axes = plt.subplots(2, 3, figsize=(28, 16))

# 定义要展示的6个收益指标及其排列顺序
metrics_row1 = ['AvR', 'S.R.', 'AnR']  # 第一行指标（值越大越好）
metrics_row2 = ['Std', 'AnV', 'Max DD']  # 第二行指标（值越小越好）
titles = {
    'AvR': 'Average Return', 
    'S.R.': 'Sharpe Ratio', 
    'Std': 'Standard Deviation',
    'AnR': 'Annualized Return', 
    'AnV': 'Annualized Volatility', 
    'Max DD': 'Maximum Drawdown'
}

# 设置位置
x_pos = np.arange(len(df_o))

# 遍历第一行的3个指标（值越大越好的指标）
for i, metric in enumerate(metrics_row1):
    ax = axes[0, i]  # 第一行的第i个子图
    
    # 获取O-Data和T-Data的指标值
    o_vals = df_o[metric].values
    t_vals = df_t[metric].values
    
    # 绘制散点图：O-Data用空心方形，T-Data用实心三角形
    ax.scatter(x_pos, o_vals, facecolors='none', edgecolors='black', marker='o', s=80, label='O-Data', zorder=5)
    ax.scatter(x_pos, t_vals, color='black', marker='D', s=80, label='T-Data', zorder=5)
    
    # 绘制连接线（从O-Data指向T-Data）
    for j, model in enumerate(df_o.index):
        o_val = o_vals[j]
        t_val = t_vals[j]
        
        # 确定线段颜色：红色表示变好（T-Data > O-Data），绿色表示变差
        color = 'red' if t_val > o_val else 'green'
        
        # 绘制带箭头的线段
        ax.annotate('', 
                   xy=(j, t_val),          # 箭头终点（T-Data）
                   xytext=(j, o_val),      # 箭头起点（O-Data）
                   arrowprops=dict(arrowstyle='->', 
                                  color=color, 
                                  lw=2,
                                  shrinkA=5,  # 箭头起点缩进
                                  shrinkB=5)  # 箭头终点缩进
                  )
    
    # 设置子图属性
    ax.set_xlabel('Models', fontsize=11, fontweight='bold')
    ax.set_ylabel(metric, fontsize=11, fontweight='bold')
    ax.set_title(f'{titles[metric]} - Except RF & XGB (High)', fontsize=13, fontweight='bold')
    ax.set_xticks(x_pos)
    ax.set_xticklabels(df_o.index, rotation=45, ha='right', fontsize=10)
    ax.legend(fontsize=10)
    # 去掉三边的边框
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)

# 遍历第二行的3个指标（值越小越好的指标）
for i, metric in enumerate(metrics_row2):
    ax = axes[1, i]  # 第二行的第i个子图
    
    # 获取O-Data和T-Data的指标值
    o_vals = df_o[metric].values
    t_vals = df_t[metric].values
    
    # 绘制散点图
    ax.scatter(x_pos, o_vals, facecolors='none', edgecolors='black', marker='o', s=80, label='O-Data', zorder=5)
    ax.scatter(x_pos, t_vals, color='black', marker='D', s=80, label='T-Data', zorder=5)

    # 绘制连接线（从O-Data指向T-Data）
    for j, model in enumerate(df_o.index):
        o_val = o_vals[j]
        t_val = t_vals[j]
        
        # 确定线段颜色：对于值越小越好的指标，红色表示变好（T-Data < O-Data），绿色表示变差
        color = 'red' if t_val < o_val else 'green'
        
        # 绘制带箭头的线段
        ax.annotate('', 
                   xy=(j, t_val),          # 箭头终点（T-Data）
                   xytext=(j, o_val),      # 箭头起点（O-Data）
                   arrowprops=dict(arrowstyle='->', 
                                  color=color, 
                                  lw=2,
                                  shrinkA=5,  # 箭头起点缩进
                                  shrinkB=5)  # 箭头终点缩进
                  )
    
    # 设置子图属性
    ax.set_xlabel('Models', fontsize=11, fontweight='bold')
    ax.set_ylabel(metric, fontsize=11, fontweight='bold')
    ax.set_title(f'{titles[metric]} - Except RF & XGB (High)', fontsize=13, fontweight='bold')
    ax.set_xticks(x_pos)
    ax.set_xticklabels(df_o.index, rotation=45, ha='right', fontsize=10)
    ax.legend(fontsize=10)
    # 去掉三边的边框
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)

# 调整布局
plt.tight_layout()

# 创建image文件夹如果不存在
os.makedirs('../image', exist_ok=True)

# 保存图片为SVG格式
plt.savefig('../image/model_profit_high_RF_XGB.svg', bbox_inches='tight')

# 显示图表
plt.show()

# %%
# 读取CSV文件
df = pd.read_csv('../CSV_results/profit_visualize.csv')

# 分别提取O-Data & High和T-Data & High的数据，并筛选RF和XGB模型
df_o = df[(df['Datasets'] == 'O-Data & High') & (df['Model'].isin(['RF', 'XGB']))].set_index('Model')
df_t = df[(df['Datasets'] == 'T-Data & High') & (df['Model'].isin(['RF', 'XGB']))].set_index('Model')

# 创建1行6列的子图画布
fig, axes = plt.subplots(1, 6, figsize=(24, 6))

# 定义要展示的6个收益指标
metrics = ['AvR', 'S.R.',  'AnR','Std', 'AnV', 'Max DD']
titles = {
    'AvR': 'Average Return', 
    'S.R.': 'Sharpe Ratio', 
    'Std': 'Standard Deviation',
    'AnR': 'Annualized Return', 
    'AnV': 'Annualized Volatility', 
    'Max DD': 'Maximum Drawdown'
}

# 设置位置
x_pos = np.arange(len(df_o))

# 遍历所有6个指标
for i, metric in enumerate(metrics):
    ax = axes[i]  # 第i个子图
    
    # 获取O-Data和T-Data的指标值
    o_vals = df_o[metric].values
    t_vals = df_t[metric].values
    
    # 绘制散点图：O-Data用空心方形，T-Data用实心三角形
    ax.scatter(x_pos, o_vals, facecolors='none', edgecolors='black', marker='s', s=120, label='O-Data', zorder=5)
    ax.scatter(x_pos, t_vals, color='black', marker='^', s=120, label='T-Data', zorder=5)
    
    # 绘制连接线（从O-Data指向T-Data）
    for j, model in enumerate(df_o.index):
        o_val = o_vals[j]
        t_val = t_vals[j]
        
        # 确定线段颜色规则
        if metric in ['Std', 'AnV', 'Max DD']:  # 值越小越好的指标
            color = 'red' if t_val < o_val else 'green'  # 红色表示变好（T-Data < O-Data）
        else:  # 值越大越好的指标
            color = 'red' if t_val > o_val else 'green'  # 红色表示变好（T-Data > O-Data）
        
        # 绘制带箭头的线段
        ax.annotate('', 
                   xy=(j, t_val),          # 箭头终点（T-Data）
                   xytext=(j, o_val),      # 箭头起点（O-Data）
                   arrowprops=dict(arrowstyle='->', 
                                  color=color, 
                                  lw=3,
                                  shrinkA=5,  # 箭头起点缩进
                                  shrinkB=5)  # 箭头终点缩进
                  )
    
    # 设置子图属性
    ax.set_xlabel('Models', fontsize=12, fontweight='bold')
    ax.set_ylabel(metric, fontsize=12, fontweight='bold')
    ax.set_title(f'{titles[metric]}', fontsize=14, fontweight='bold')
    ax.set_xticks(x_pos)
    ax.set_xticklabels(df_o.index, rotation=45, ha='right', fontsize=11)
    ax.legend(fontsize=11)
    # 去掉三边的边框
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)

# 调整布局
plt.tight_layout()

# 创建image文件夹如果不存在
os.makedirs('../image', exist_ok=True)

# 保存图片为SVG格式
plt.savefig('../image/model_profit_high_except_RF_XGB.svg', bbox_inches='tight')

# 显示图表
plt.show()

# %%
# 读取CSV文件
df = pd.read_csv('../CSV_results/profit_visualize.csv')

# 分别提取O-Data & Close和O-Data & High的数据
df_close = df[df['Datasets'] == 'O-Data & Close'].set_index('Model')
df_high = df[df['Datasets'] == 'O-Data & High'].set_index('Model')

# 创建2行3列的子图画布
fig, axes = plt.subplots(2, 3, figsize=(28, 16))

# 定义要展示的6个收益指标及其排列顺序
metrics_row1 = ['AvR', 'S.R.', 'AnR']  # 第一行指标
metrics_row2 = ['Std', 'AnV', 'Max DD']  # 第二行指标
titles = {
    'AvR': 'Average Return', 
    'S.R.': 'Sharpe Ratio', 
    'Std': 'Standard Deviation',
    'AnR': 'Annualized Return', 
    'AnV': 'Annualized Volatility', 
    'Max DD': 'Maximum Drawdown'
}

# 设置位置
x_pos = np.arange(len(df_close))

# 遍历第一行的3个指标
for i, metric in enumerate(metrics_row1):
    ax = axes[0, i]  # 第一行的第i个子图
    
    # 获取Close和High的指标值
    close_vals = df_close[metric].values
    high_vals = df_high[metric].values
    
    # 绘制散点图：Close用空心方形，High用实心三角形
    ax.scatter(x_pos, close_vals, facecolors='none', edgecolors='black', marker='s', s=50, label='Close', zorder=5)
    ax.scatter(x_pos, high_vals, color='black', marker='^', s=50, label='High', zorder=5)
    
    # 绘制连接线（从Close指向High）
    for j, model in enumerate(df_close.index):
        close_val = close_vals[j]
        high_val = high_vals[j]
        
        # 确定线段颜色：红色表示变好（High > Close），绿色表示变差
        color = 'red' if high_val > close_val else 'green'
        
        # 绘制带箭头的线段
        ax.annotate('', 
                   xy=(j, high_val),          # 箭头终点（High）
                   xytext=(j, close_val),     # 箭头起点（Close）
                   arrowprops=dict(arrowstyle='->', 
                                  color=color, 
                                  lw=2,
                                  shrinkA=5,  # 箭头起点缩进
                                  shrinkB=5)  # 箭头终点缩进
                  )
    
    # 设置子图属性
    ax.set_xlabel('Models', fontsize=10, fontweight='bold')
    ax.set_ylabel(metric, fontsize=10, fontweight='bold')
    ax.set_title(titles[metric], fontsize=12, fontweight='bold')
    ax.set_xticks(x_pos)
    ax.set_xticklabels(df_close.index, rotation=45, ha='right')
    ax.legend()
    # 去掉三边的边框
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)

# 遍历第二行的3个指标（值越小越好的指标）
for i, metric in enumerate(metrics_row2):
    ax = axes[1, i]  # 第二行的第i个子图
    
    # 获取Close和High的指标值
    close_vals = df_close[metric].values
    high_vals = df_high[metric].values
    
    # 绘制散点图
    ax.scatter(x_pos, close_vals, facecolors='none', edgecolors='black', marker='s', s=50, label='Close', zorder=5)
    ax.scatter(x_pos, high_vals, color='black', marker='^', s=50, label='High', zorder=5)

    # 绘制连接线（从Close指向High）
    for j, model in enumerate(df_close.index):
        close_val = close_vals[j]
        high_val = high_vals[j]
        
        # 确定线段颜色：对于值越小越好的指标，红色表示变好（High < Close），绿色表示变差
        color = 'red' if high_val < close_val else 'green'
        
        # 绘制带箭头的线段
        ax.annotate('', 
                   xy=(j, high_val),          # 箭头终点（High）
                   xytext=(j, close_val),     # 箭头起点（Close）
                   arrowprops=dict(arrowstyle='->', 
                                  color=color, 
                                  lw=2,
                                  shrinkA=5,  # 箭头起点缩进
                                  shrinkB=5)  # 箭头终点缩进
                  )
    
    # 设置子图属性
    ax.set_xlabel('Models', fontsize=10, fontweight='bold')
    ax.set_ylabel(metric, fontsize=10, fontweight='bold')
    ax.set_title(titles[metric], fontsize=12, fontweight='bold')
    ax.set_xticks(x_pos)
    ax.set_xticklabels(df_close.index, rotation=45, ha='right')
    ax.legend()
    # 去掉三边的边框
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)

# 调整布局
plt.tight_layout()

# 创建image文件夹如果不存在
os.makedirs('../image', exist_ok=True)

# 保存图片为SVG格式
plt.savefig('../image/model_profit_O-Data.svg', bbox_inches='tight')

# 显示图表
plt.show()

# %%
# 读取CSV文件
df = pd.read_csv('../CSV_results/profit_visualize.csv')

# 分别提取T-Data & Close和T-Data & High的数据
df_close = df[df['Datasets'] == 'T-Data & Close'].set_index('Model')
df_high = df[df['Datasets'] == 'T-Data & High'].set_index('Model')

# 创建2行3列的子图画布
fig, axes = plt.subplots(2, 3, figsize=(28, 16))

# 定义要展示的6个收益指标及其排列顺序
metrics_row1 = ['AvR', 'S.R.', 'AnR']  # 第一行指标
metrics_row2 = ['Std', 'AnV', 'Max DD']  # 第二行指标
titles = {
    'AvR': 'Average Return', 
    'S.R.': 'Sharpe Ratio', 
    'Std': 'Standard Deviation',
    'AnR': 'Annualized Return', 
    'AnV': 'Annualized Volatility', 
    'Max DD': 'Maximum Drawdown'
}

# 设置位置
x_pos = np.arange(len(df_close))

# 遍历第一行的3个指标
for i, metric in enumerate(metrics_row1):
    ax = axes[0, i]  # 第一行的第i个子图
    
    # 获取Close和High的指标值
    close_vals = df_close[metric].values
    high_vals = df_high[metric].values
    
    # 绘制散点图：Close用空心方形，High用实心三角形
    ax.scatter(x_pos, close_vals, facecolors='none', edgecolors='black', marker='s', s=50, label='Close', zorder=5)
    ax.scatter(x_pos, high_vals, color='black', marker='^', s=50, label='High', zorder=5)
    
    # 绘制连接线（从Close指向High）
    for j, model in enumerate(df_close.index):
        close_val = close_vals[j]
        high_val = high_vals[j]
        
        # 确定线段颜色：红色表示变好（High > Close），绿色表示变差
        color = 'red' if high_val > close_val else 'green'
        
        # 绘制带箭头的线段
        ax.annotate('', 
                   xy=(j, high_val),          # 箭头终点（High）
                   xytext=(j, close_val),     # 箭头起点（Close）
                   arrowprops=dict(arrowstyle='->', 
                                  color=color, 
                                  lw=2,
                                  shrinkA=5,  # 箭头起点缩进
                                  shrinkB=5)  # 箭头终点缩进
                  )
    
    # 设置子图属性
    ax.set_xlabel('Models', fontsize=10, fontweight='bold')
    ax.set_ylabel(metric, fontsize=10, fontweight='bold')
    ax.set_title(titles[metric], fontsize=12, fontweight='bold')
    ax.set_xticks(x_pos)
    ax.set_xticklabels(df_close.index, rotation=45, ha='right')
    ax.legend()
    # 去掉三边的边框
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)

# 遍历第二行的3个指标（值越小越好的指标）
for i, metric in enumerate(metrics_row2):
    ax = axes[1, i]  # 第二行的第i个子图
    
    # 获取Close和High的指标值
    close_vals = df_close[metric].values
    high_vals = df_high[metric].values
    
    # 绘制散点图
    ax.scatter(x_pos, close_vals, facecolors='none', edgecolors='black', marker='s', s=50, label='Close', zorder=5)
    ax.scatter(x_pos, high_vals, color='black', marker='^', s=50, label='High', zorder=5)

    # 绘制连接线（从Close指向High）
    for j, model in enumerate(df_close.index):
        close_val = close_vals[j]
        high_val = high_vals[j]
        
        # 确定线段颜色：对于值越小越好的指标，红色表示变好（High < Close），绿色表示变差
        color = 'red' if high_val < close_val else 'green'
        
        # 绘制带箭头的线段
        ax.annotate('', 
                   xy=(j, high_val),          # 箭头终点（High）
                   xytext=(j, close_val),     # 箭头起点（Close）
                   arrowprops=dict(arrowstyle='->', 
                                  color=color, 
                                  lw=2,
                                  shrinkA=5,  # 箭头起点缩进
                                  shrinkB=5)  # 箭头终点缩进
                  )
    
    # 设置子图属性
    ax.set_xlabel('Models', fontsize=10, fontweight='bold')
    ax.set_ylabel(metric, fontsize=10, fontweight='bold')
    ax.set_title(titles[metric], fontsize=12, fontweight='bold')
    ax.set_xticks(x_pos)
    ax.set_xticklabels(df_close.index, rotation=45, ha='right')
    ax.legend()
    # 去掉三边的边框
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)

# 调整布局
plt.tight_layout()

# 创建image文件夹如果不存在
os.makedirs('../image', exist_ok=True)

# 保存图片为SVG格式
plt.savefig('../image/model_profit_T-Data.svg', bbox_inches='tight')

# 显示图表
plt.show()

# %%
#  读取数据
df = pd.read_csv('../CSV_results/profit_visualize_all.csv', index_col=0)

# 提取唯一的月份作为x轴
months = df.index.unique()

# 提取四种不同的数据集类型
datasets = df['Datasets'].unique()

# 提取所有模型列（排除Month和Datasets列）
models = df.columns[2:]

# 设置颜色和线型
colors = [ 'green', 'orange','blue', 'red', 'black']  # 增加黑色用于CSI 300
linestyles = ['-', '--', '-.', ':', '-']

# 创建画布和子图 - 5行3列
fig, axes = plt.subplots(5, 3, figsize=(18, 24)) 
axes = axes.flatten()

# 为每个模型创建一个子图
for i, model in enumerate(models):
    if i >= len(axes):  # 确保不超过子图数量
        break
        
    ax = axes[i]
    
    # 为每种数据集绘制折线
    for j, dataset in enumerate(datasets):
        # 筛选特定数据集和模型的数据
        subset = df[df['Datasets'] == dataset]
        values = subset[model].values
        
        # 绘制折线
        ax.plot(months, values, 
                color=colors[j], 
                linestyle=linestyles[j], 
                label=dataset,
                linewidth=1.5)
    
    # 添加CSI 300作为对比（使用第一个数据集的数据，因为CSI 300值相同）
    csi_data = df[df['Datasets'] == datasets[0]]['CSI 300'].values
    ax.plot(months, csi_data, 
            color='black', 
            linestyle='-', 
            label='CSI 300',
            linewidth=2,
            alpha=0.7)
    
    # 设置子图标题和标签
    ax.set_title(f'{model}', fontsize=12, fontweight='bold')
    ax.set_xlabel('Date', fontsize=10)
    ax.set_ylabel('Cumulative return', fontsize=10)
    
    # 去掉三边的边框
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    
    # 添加图例
    ax.legend(fontsize=8, loc='best')
    
    # 优化x轴标签显示 - 每6个月显示一个标签
    x_ticks = range(0, len(months), 6)
    ax.set_xticks(x_ticks)
    ax.set_xticklabels([months[i] for i in x_ticks], rotation=45, ha='right')
    
    # 设置y轴范围，确保所有数据都能显示
    ax.autoscale(enable=True, axis='y')

# 隐藏多余的空子图
for i in range(len(models), len(axes)):
    axes[i].set_visible(False)

# 添加画布总标题
plt.suptitle('Cumulative Returns of All models with all Datasets vs CSI 300', 
             fontsize=16, fontweight='bold', y=1)
# 调整布局
plt.tight_layout()
# 创建image文件夹如果不存在
os.makedirs('../image', exist_ok=True)
# 保存图片为SVG格式
plt.savefig('../image/model_profit_all.svg', bbox_inches='tight')

# 显示图形
plt.show()

# %%
# 读取数据
df = pd.read_csv('../CSV_results/profit_predictability.csv')

# 提取唯一的dataset类型和模型类型
datasets = df['Datasets'].unique()
models = df['Model'].unique()

# 为每个模型分配唯一的颜色
model_colors = plt.cm.tab20(np.linspace(0, 1, len(models)))
model_color_dict = dict(zip(models, model_colors))

fig, axes = plt.subplots(2, 2, figsize=(16, 12))
axes = axes.flatten()

for i, dataset in enumerate(datasets):
    ax = axes[i]
    subset = df[df['Datasets'] == dataset]
    
    for model in models:
        model_data = subset[subset['Model'] == model]
        if not model_data.empty:
            color = model_color_dict[model]
            ax.scatter(model_data['S.R.'], model_data['Predictability (%)'],
                      color=color,
                      s=100,
                      alpha=0.8,
                      edgecolors='black',
                      linewidth=0.8,
                      label=model)
    
    ax.set_title(f'{dataset}', fontsize=14, fontweight='bold')
    ax.set_xlabel('Profitability (S.R.)', fontsize=12)
    ax.set_ylabel('Predictability (%)', fontsize=12)
    # ax.grid(True, alpha=0.3)
    
    # 在每个子图中添加图例
    ax.legend()

    # 去掉三边的边框
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    # 添加网格
    ax.grid(True, alpha=0.2, linestyle='--')
    
    # 设置坐标轴范围
    x_margin = (subset['S.R.'].max() - subset['S.R.'].min()) * 0.1
    y_margin = (subset['Predictability (%)'].max() - subset['Predictability (%)'].min()) * 0.1
    ax.set_xlim(subset['S.R.'].min() - x_margin, subset['S.R.'].max() + x_margin)
    ax.set_ylim(subset['Predictability (%)'].min() - y_margin, subset['Predictability (%)'].max() + y_margin)

plt.suptitle('Profitability (S.R.) vs Predictability (%) by Model and Datasets', 
             fontsize=16, fontweight='bold', y=1)
plt.tight_layout()
# 创建image文件夹如果不存在
os.makedirs('../image', exist_ok=True)
# 保存图片为SVG格式
plt.savefig('../image/profit_predictability_all.svg', bbox_inches='tight')
plt.show()

# %%
# 读取数据
df = pd.read_csv('../CSV_results/profit_predictability.csv')

# 提取模型类型和数据类型
models = df['Model'].unique()
datasets = df['Datasets'].unique()

# 为每个模型分配唯一的颜色
model_colors = plt.cm.tab20(np.linspace(0, 1, len(models)))
model_color_dict = dict(zip(models, model_colors))

# 定义Close和High的不同标记形状
marker_dict = {
    'O-Data & Close': 'o',      # 圆圈
    'T-Data & Close': 's',      # 正方形
    'O-Data & High': '^',       # 三角形
    'T-Data & High': 'D'        # 菱形
}

# 创建单个图形
fig, ax = plt.subplots(figsize=(14, 8))

# 绘制所有数据点，按模型颜色和数据类型标记形状区分
for model in models:
    model_data = df[df['Model'] == model]
    color = model_color_dict[model]
    
    for dataset in datasets:
        dataset_data = model_data[model_data['Datasets'] == dataset]
        if not dataset_data.empty:
            marker = marker_dict[dataset]
            ax.scatter(dataset_data['S.R.'], dataset_data['Predictability (%)'],
                      color=color,
                      s=100,
                      alpha=0.8,
                      edgecolors='black',
                      linewidth=0.8,
                      marker=marker)

ax.set_xlabel('Sharpe Ratio (S.R.)', fontsize=12)
ax.set_ylabel('Predictability (%)', fontsize=12)

# 创建组合图例
legend_handles = []

# 添加模型颜色的图例项
for model in models:
    legend_handles.append(Line2D([0], [0], marker='o', color='w', 
                                markerfacecolor=model_color_dict[model], 
                                markersize=10, label=model))

# 添加分隔线
legend_handles.append(Line2D([0], [0], linestyle='none', label=''))

# 添加数据类型标记形状的图例项
for dataset in datasets:
    legend_handles.append(Line2D([0], [0], marker=marker_dict[dataset], color='w', 
                               markerfacecolor='gray', markersize=10, 
                               label=dataset.replace('Data & ', '')))

# 添加单个图例
ax.legend(handles=legend_handles, title="Models & Data Types", 
          bbox_to_anchor=(1.05, 1), loc='upper left', frameon=True,
          fancybox=True, shadow=True)

# 去掉三边的边框
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
# 添加网格
ax.grid(True, alpha=0.2, linestyle='--')

# 设置坐标轴范围
x_margin = (df['S.R.'].max() - df['S.R.'].min()) * 0.1
y_margin = (df['Predictability (%)'].max() - df['Predictability (%)'].min()) * 0.1
ax.set_xlim(df['S.R.'].min() - x_margin, df['S.R.'].max() + x_margin)
ax.set_ylim(df['Predictability (%)'].min() - y_margin, df['Predictability (%)'].max() + y_margin)

# 设置标题
plt.title('Profitability (S.R.) vs Predictability (%) by Model and Datasets', 
          fontsize=16, fontweight='bold', pad=20)

plt.tight_layout()

# 创建image文件夹如果不存在
os.makedirs('../image', exist_ok=True)
# 保存图片为SVG格式
plt.savefig('../image/profit_predictability.svg', bbox_inches='tight')
plt.show()

# %%
# 读取数据
df = pd.read_csv('../CSV_results/profit_predictability.csv')

# 只选择包含"High"的数据集，并排除RF和XGB模型
high_data = df[df['Datasets'].str.contains('High') & 
               ~df['Model'].isin(['RF', 'XGB'])]

# 提取模型类型
models = high_data['Model'].unique()

# 为每个模型分配唯一的颜色
model_colors = plt.cm.tab20(np.linspace(0, 1, len(models)))
model_color_dict = dict(zip(models, model_colors))

# 创建画布和子图 - 1行2列
fig, axes = plt.subplots(1, 2, figsize=(16, 8))
axes = axes.flatten()

# 为每个数据集创建散点图
datasets = ['O-Data & High', 'T-Data & High']

for i, dataset in enumerate(datasets):
    ax = axes[i]
    
    # 筛选特定数据集的数据
    dataset_data = high_data[high_data['Datasets'] == dataset]
    
    # 绘制该数据集的所有模型数据点
    for model in models:
        model_data = dataset_data[dataset_data['Model'] == model]
        if not model_data.empty:
            color = model_color_dict[model]
            ax.scatter(model_data['S.R.'], model_data['Predictability (%)'],
                      color=color,
                      s=100,
                      alpha=0.8,
                      edgecolors='black',
                      linewidth=0.8,
                      label=model)
    
    ax.set_xlabel('Profitability (S.R.)', fontsize=12)
    ax.set_ylabel('Predictability (%)', fontsize=12)
    ax.set_title(f'{dataset}', fontsize=14, fontweight='bold')
    
    # 去掉三边的边框
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    
    # 设置坐标轴范围
    x_margin = (dataset_data['S.R.'].max() - dataset_data['S.R.'].min()) * 0.1
    y_margin = (dataset_data['Predictability (%)'].max() - dataset_data['Predictability (%)'].min()) * 0.1
    ax.set_xlim(dataset_data['S.R.'].min() - x_margin, dataset_data['S.R.'].max() + x_margin)
    ax.set_ylim(dataset_data['Predictability (%)'].min() - y_margin, dataset_data['Predictability (%)'].max() + y_margin)
    
    # 添加网格
    ax.grid(True, alpha=0.2, linestyle='--')

# 创建统一的图例
handles, labels = axes[0].get_legend_handles_labels()
fig.legend(handles, labels, 
           title="Models",
           loc='lower right',
           bbox_to_anchor=(1.05, 0.5),
           fontsize=10,
           frameon=True,
           fancybox=True,
           shadow=True)

# 设置总标题
plt.suptitle('Profitability (S.R.) vs Predictability (%) (Excluding RF & XGB)', 
             fontsize=16, fontweight='bold', y=1)

plt.tight_layout()
# plt.subplots_adjust(right=0.85)  # 为图例留出空间

# 创建image文件夹如果不存在
os.makedirs('../image', exist_ok=True)
# 保存图片为SVG格式
plt.savefig('../image/profit_predictability_high_separate.svg', bbox_inches='tight')
plt.show()

# %%
# 读取数据
df = pd.read_csv('../CSV_results/feature_importance.csv')

# 按重要性排序数据
df_sorted = df.sort_values('Reduction of S.R.', ascending=True)

# 创建图形
plt.figure(figsize=(12, 8))

# 创建从红到绿的颜色渐变
colors = plt.cm.RdYlGn_r(np.linspace(0, 1, len(df))) 

# 创建水平条形图
bars = plt.barh(df_sorted['Category'], df_sorted['Reduction of S.R.'], 
                color=colors,
                alpha=0.8,
                edgecolor='black',
                linewidth=0.5)

# 添加数值标签
for i, (value, category) in enumerate(zip(df_sorted['Reduction of S.R.'], df_sorted['Category'])):
    plt.text(value + 0.0005, i, f'{value:.4f}', 
             va='center', fontsize=10, fontweight='bold')

# 设置标题和标签
plt.title('Feature Importance - Reduction of Sharpe Ratio', 
          fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Reduction of S.R.', fontsize=12)
plt.ylabel('Feature Category', fontsize=12)
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)


# 美化图表
plt.grid(axis='x', alpha=0.3, linestyle='--')
plt.tight_layout()

# 创建image文件夹如果不存在
os.makedirs('../image', exist_ok=True)
# 保存为SVG格式
plt.savefig('../image/feature_importance.svg', bbox_inches='tight')

plt.show()
